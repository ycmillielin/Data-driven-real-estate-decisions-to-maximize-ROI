# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import censusdata
import requests

# %% [markdown]
# # Import Property Data

# %%
florida=pd.read_csv('FloridaMappedData2.csv', converters={'tract': lambda x: np.int64(x),'PROPERTY_ZIPCODE':lambda x: int(x)})
#dataframe = read_csv('projects.csv', converters={'project_id': lambda x: str(x)})

florida=florida.drop(florida.columns[0],axis=1)
#florida['tract']=florida['tract'].apply(lambda x: str(x).zfill(11))
#florida['PROPERTY_ZIPCODE']=florida['PROPERTY_ZIPCODE'].apply(lambda x: str(x).zfill(5))
florida['region']='f'
florida.head()
# Out:
#   PROPERTY_ID  MARKETID   MARKET_NAME  SUBMARKET_CODE    SUBMARKET_NAME  \
# 0  57_1345491        57  Jacksonville            29.0    Fleming Island
# 1     57_1937        57  Jacksonville            29.0    Fleming Island
# 2     57_1936        57  Jacksonville            29.0    Fleming Island
# 3     57_3062        57  Jacksonville            26.0          Callahan
# 4     57_1909        57  Jacksonville            24.0  Fernandina Beach
#
#   COUNTY_NAME                 PROPERTY_NAME         PROPERTY_PRIORNAMES  \
# 0        Clay   Station Fleming Island, The                Station, The
# 1        Clay   Cobblestone at Eagle Harbor  Vineyards at Eagle Harbour
# 2        Clay  Lighthouse at Fleming Island            Lighthouse Court
# 3      Nassau      Pine Terrace I, II & III                         NaN
# 4      Nassau           Pepper Tree Village                         NaN
#
#          PROPERTY_ADDRESS     PROPERTY_CITY  ... PROPERTY_AGERESTRICTED  \
# ...

# %%
south=pd.read_csv('SouthMappedData2.csv', converters={'tract': lambda x: int(x),'PROPERTY_ZIPCODE':lambda x: int(x)})
south=south.drop(south.columns[0],axis=1)
#south['tract']=south['tract'].apply(lambda x: str(x).zfill(11))
#south['PROPERTY_ZIPCODE']=south['PROPERTY_ZIPCODE'].apply(lambda x: str(x).zfill(5))
south['region']='s'
south.head()
# Out:
#   PROPERTY_ID  MARKETID  MARKET_NAME  SUBMARKET_CODE          SUBMARKET_NAME  \
# 0      54_106        54  Little Rock            17.0            Jacksonville
# 1  54_1189257        54  Little Rock            10.0             John Barrow
# 2  54_1307778        54  Little Rock             9.0              Rock Creek
# 3  54_1314693        54  Little Rock            10.0             John Barrow
# 4  54_1315317        54  Little Rock             1.0  Little Rock - Downtown
#
#   COUNTY_NAME                       PROPERTY_NAME PROPERTY_PRIORNAMES  \
# 0     Pulaski          Park Place of Jacksonville       William Manor
# 1     Pulaski  Ridge at Little Rock Phase II, The                 NaN
# 2     Pulaski              McKenzie Park Phase II                 NaN
# 3     Pulaski                Ascent at Aldersgate                 NaN
# 4     Pulaski            1111 West Capitol Avenue                 NaN
#
#            PROPERTY_ADDRESS PROPERTY_CITY  ... PROPERTY_AGERESTRICTED  \
# ...

# %%
southeast=pd.read_csv('SouthEastMappedData2.csv', converters={'tract': lambda x: int(x),'PROPERTY_ZIPCODE':lambda x: int(x)})
southeast=southeast.drop(southeast.columns[0],axis=1)
#southeast['tract']=southeast['tract'].apply(lambda x: str(x).zfill(11))
#southeast['PROPERTY_ZIPCODE']=southeast['PROPERTY_ZIPCODE'].apply(lambda x: str(x).zfill(5))
southeast['region']='se'

southeast
# Out:
#       PROPERTY_ID  MARKETID      MARKET_NAME  SUBMARKET_CODE  \
# 0        22_11364        22  Atlanta - Urban            21.0
# 1      22_1139950        22  Atlanta - Urban            15.0
# 2      22_1140162        22  Atlanta - Urban            10.0
# 3      22_1154040        22  Atlanta - Urban            19.0
# 4        22_11594        22  Atlanta - Urban            14.0
# ...           ...       ...              ...             ...
# 8615  163_1358383       163           Athens            12.0
# 8616  163_1392242       163           Athens             4.0
# 8617   163_928806       163           Athens            12.0
# 8618   163_928869       163           Athens            11.0
# 8619   163_928873       163           Athens             3.0
#
#                              SUBMARKET_NAME COUNTY_NAME  \
# 0                            South Buckhead      Fulton
# 1                             Midtown South      Fulton
# 2     Grant Park/East Atlanta/Panthersville      Fulton
# ...

# %%
west=pd.read_csv('WestMappedData2.csv', converters={'tract': lambda x: int(x),'PROPERTY_ZIPCODE':lambda x: int(x)})
west=west.drop(west.columns[0],axis=1)
#west['tract']=west['tract'].apply(lambda x: str(x).zfill(11))
#west['PROPERTY_ZIPCODE']=west['PROPERTY_ZIPCODE'].apply(lambda x: str(x).zfill(5))
west['region']='w'

west.head()
# Out:
#   PROPERTY_ID  MARKETID MARKET_NAME SUBMARKET_CODE         SUBMARKET_NAME  \
# 0      1_1004         1     Phoenix            17N             North Mesa
# 1      1_1024         1     Phoenix             2N  North Paradise Valley
# 2      1_1030         1     Phoenix             10   Central East Phoenix
# 3       1_104         1     Phoenix            21E            Union Hills
# 4      1_1091         1     Phoenix              3             Sunnyslope
#
#   COUNTY_NAME      PROPERTY_NAME PROPERTY_PRIORNAMES         PROPERTY_ADDRESS  \
# 0    Maricopa            Maga̱a            Parkview  1628 East Broadway Road
# 1    Maricopa    Mission Springs                 NaN  16818 North 56th Street
# 2    Maricopa      Papago Buttes                 NaN    402 North 52nd Street
# 3    Maricopa  Courtyard Village         La Miradora  17609 North 19th Avenue
# 4    Maricopa       Sahuaro West                 NaN  1650 West Sahuaro Drive
#
# ...

# %%
southwest=pd.read_csv('SouthWestMappedData2.csv', converters={'tract': lambda x: int(x),'PROPERTY_ZIPCODE':lambda x: int(x)})
southwest=southwest.drop(southwest.columns[0],axis=1)
#southwest['tract']=southwest['tract'].apply(lambda x: str(x).zfill(11))
#southwest['PROPERTY_ZIPCODE']=southwest['PROPERTY_ZIPCODE'].apply(lambda x: str(x).zfill(5))
southwest['region']='sw'

southwest.head()
# Out:
#   PROPERTY_ID  MARKETID MARKET_NAME  SUBMARKET_CODE           SUBMARKET_NAME  \
# 0      36_103        36      Austin            38.0          San Marcos/Kyle
# 1     36_1091        36      Austin            22.0            Capital Plaza
# 2  36_1097559        36      Austin            10.0             Pflugerville
# 3  36_1140137        36      Austin            40.0  Outlying Bastrop County
# 4      36_115        36      Austin            38.0          San Marcos/Kyle
#
#   COUNTY_NAME        PROPERTY_NAME PROPERTY_PRIORNAMES  \
# 0        Hays  Executive Townhomes                 NaN
# 1      Travis        Capital Steps                 NaN
# 2      Travis  Old Gin Pforum, The                 NaN
# 3     Bastrop     Post Oak at Hill                 NaN
# 4        Hays              Langtry                 NaN
#
#          PROPERTY_ADDRESS PROPERTY_CITY  ... PROPERTY_AGERESTRICTED  \
# 0     317 Craddock Avenue    San Marcos  ...                      N
# ...

# %%
south_cali=pd.read_csv('SouthernCaliforniaMappedData2.csv', converters={'tract': lambda x: int(x),'PROPERTY_ZIPCODE':lambda x: int(x)})
south_cali=south_cali.drop(south_cali.columns[0],axis=1)
#south_cali['tract']=south_cali['tract'].apply(lambda x: str(x).zfill(11))
#south_cali['PROPERTY_ZIPCODE']=south_cali['PROPERTY_ZIPCODE'].apply(lambda x: str(x).zfill(5))
south_cali['region']='sc'

south_cali.head()
# Out:
#   PROPERTY_ID  MARKETID MARKET_NAME  SUBMARKET_CODE     SUBMARKET_NAME  \
# 0   3_1004725         3   San Diego            20.0            La Mesa
# 1       3_108         3   San Diego            31.0              Vista
# 2   3_1108464         3   San Diego             1.0  Central San Diego
# 3   3_1153863         3   San Diego            28.0          Oceanside
# 4       3_117         3   San Diego            27.0           Carlsbad
#
#   COUNTY_NAME          PROPERTY_NAME PROPERTY_PRIORNAMES  \
# 0   San Diego      Touchstone Villas       Aldea La Mesa
# 1   San Diego          Sunset Cliffs                 NaN
# 2   San Diego  Arbor Crest on Fourth       Arbor Terrace
# 3   San Diego       Rincon Oceanside                 NaN
# 4   San Diego            San Katrina                 NaN
#
#        PROPERTY_ADDRESS PROPERTY_CITY  ... PROPERTY_FRACTUREDCONDO  \
# 0    7808 El Cajon Blvd       La Mesa  ...                     NaN
# ...

# %%
property_value=pd.read_csv('AllRegionsPropertyValue_new.csv',converters={'PROPERTY_ZIPCODE':lambda x: int(x)})
property_value=property_value.rename(columns={'Avg_OccupancyRate': 'property_value','RegionName':'PROPERTY_ZIPCODE','Year':'year'}).drop(columns=['Unnamed: 0'])


property_value
# Out:
#         PROPERTY_ZIPCODE  year  property_value
# 0                   1001  2016   195623.583333
# 1                   1001  2017   203795.916667
# 2                   1001  2018   214829.083333
# 3                   1001  2019   220684.166667
# 4                   1001  2020   232598.833333
# ...                  ...   ...             ...
# 191368             99901  2018   295226.083333
# 191369             99901  2019   305604.833333
# 191370             99901  2020   313048.166667
# 191371             99901  2021   332832.166667
# 191372             99901  2022   355763.750000
#
# [191373 rows x 3 columns]

# %% [markdown]
# # Import Time Series Data

# %% [markdown]
# **Rent (Gross) data**

# %%
FL_rent=pd.read_csv('FloridaRentActual.csv', index_col = 0)
FL_rent=FL_rent.rename(columns={'Year':'year'})
FL_rent.head()
# Out:
#   PROPERTY_ID  year  Avg_RentActual
# 0       101_1  2016      697.500000
# 1       101_1  2017      700.916667
# 2       101_1  2018      772.250000
# 3       101_1  2019      855.500000
# 4       101_1  2020      860.250000

# %%
SoCal_rent=pd.read_csv('SoCalRentActual.csv', index_col = 0)
SoCal_rent=SoCal_rent.rename(columns={'Year':'year'})
SoCal_rent.head()
# Out:
#   PROPERTY_ID  year  Avg_RentActual
# 0        10_1  2016     1725.666667
# 1        10_1  2017     1757.833333
# 2        10_1  2018     1864.333333
# 3        10_1  2019     1948.250000
# 4        10_1  2020     2024.750000

# %%
SE_rent=pd.read_csv('SoutheastRentActual.csv', index_col = 0)
SE_rent=SE_rent.rename(columns={'Year':'year'})
SE_rent.head()
# Out:
#   PROPERTY_ID  year  Avg_RentActual
# 0     107_100  2016     1176.416667
# 1     107_100  2017     1252.250000
# 2     107_100  2018     1301.583333
# 3     107_100  2019     1285.416667
# 4     107_100  2020     1256.916667

# %%
South_rent=pd.read_csv('SouthRentActual.csv', index_col = 0)
South_rent=South_rent.rename(columns={'Year':'year'})
South_rent.head()
# Out:
#   PROPERTY_ID  year  Avg_RentActual
# 0       104_1  2016      512.666667
# 1       104_1  2017      527.083333
# 2       104_1  2018      566.000000
# 3       104_1  2019      603.250000
# 4       104_1  2020      698.833333

# %%
SW_rent=pd.read_csv('SouthwestRentActual.csv', index_col = 0)
SW_rent=SW_rent.rename(columns={'Year':'year'})
SW_rent.head()
# Out:
#   PROPERTY_ID  year  Avg_RentActual
# 0       111_1  2016      938.583333
# 1       111_1  2017      951.916667
# 2       111_1  2018      957.250000
# 3       111_1  2019      994.000000
# 4       111_1  2020      986.583333

# %%
West_rent=pd.read_csv('WesternRentActual.csv', index_col = 0)
West_rent=West_rent.rename(columns={'Year':'year'})
West_rent.head()
# Out:
#   PROPERTY_ID  year  Avg_RentActual
# 0      109_10  2016      772.000000
# 1      109_10  2017      826.916667
# 2      109_10  2018      879.833333
# 3      109_10  2019     1003.500000
# 4      109_10  2020     1071.583333

# %% [markdown]
# **Rent Per Sq Foot data**

# %%
FL_rent_per=pd.read_csv('FloridaRentPerSqFTActual.csv', index_col = 0)
FL_rent_per=FL_rent_per.rename(columns={'Year':'year'})
FL_rent_per.head()
# Out:
#   PROPERTY_ID  year  Avg_RentPerSqFtActual
# 0       101_1  2016               0.838333
# 1       101_1  2017               0.843333
# 2       101_1  2018               0.928333
# 3       101_1  2019               1.030833
# 4       101_1  2020               1.035833

# %%
FL_rent_per.isnull().sum()
# Out:
# PROPERTY_ID                 0
# year                        0
# Avg_RentPerSqFtActual    4429
# dtype: int64

# %%
SoCal_rent_per=pd.read_csv('SoCalRentPerSqFTActual.csv', index_col = 0)
SoCal_rent_per=SoCal_rent_per.rename(columns={'Year':'year'})
SoCal_rent_per.head()
# Out:
#   PROPERTY_ID  year  Avg_RentPerSqFtActual
# 0        10_1  2016               1.766667
# 1        10_1  2017               1.800833
# 2        10_1  2018               1.909167
# 3        10_1  2019               1.994167
# 4        10_1  2020               2.075000

# %%
SE_rent_per=pd.read_csv('SoutheastRentPerSqFTActual.csv', index_col = 0)
SE_rent_per=SE_rent_per.rename(columns={'Year':'year'})
SE_rent_per.head()
# Out:
#   PROPERTY_ID  year  Avg_RentPerSqFtActual
# 0     107_100  2016               1.140833
# 1     107_100  2017               1.215833
# 2     107_100  2018               1.264167
# 3     107_100  2019               1.247500
# 4     107_100  2020               1.220000

# %%
South_rent_per=pd.read_csv('SouthRentPerSqFTActual.csv', index_col = 0)
South_rent_per=South_rent_per.rename(columns={'Year':'year'})
South_rent_per.head()
# Out:
#   PROPERTY_ID  year  Avg_RentPerSqFtActual
# 0       104_1  2016               0.779167
# 1       104_1  2017               0.801667
# 2       104_1  2018               0.864167
# 3       104_1  2019               0.916667
# 4       104_1  2020               1.067500

# %%
SW_rent_per=pd.read_csv('SouthwestRentPerSqFTActual.csv')
SW_rent_per=SW_rent_per.rename(columns={'Year':'year'})
SW_rent_per
# Out:
#        Unnamed: 0 PROPERTY_ID  year  Avg_RentPerSqFtActual
# 0               0       111_1  2016               1.004167
# 1               1       111_1  2017               1.020000
# 2               2       111_1  2018               1.025000
# 3               3       111_1  2019               1.064167
# 4               4       111_1  2020               1.056667
# ...           ...         ...   ...                    ...
# 67720       67720       94_99  2018               0.746667
# 67721       67721       94_99  2019               0.735000
# 67722       67722       94_99  2020               0.748333
# 67723       67723       94_99  2021               0.754167
# 67724       67724       94_99  2022               0.778000
#
# [67725 rows x 4 columns]

# %%
West_rent_per=pd.read_csv('WesternRentPerSqFTActual.csv', index_col = 0)
West_rent_per=West_rent_per.rename(columns={'Year':'year'})
West_rent_per.head()
# Out:
#   PROPERTY_ID  year  Avg_RentPerSqFtActual
# 0      109_10  2016               0.821667
# 1      109_10  2017               0.880000
# 2      109_10  2018               0.935000
# 3      109_10  2019               1.065833
# 4      109_10  2020               1.140000

# %% [markdown]
# # Import Third Party Data

# %% [markdown]
# **Economics data**

# %%
bond=pd.read_csv('bond.csv')
bond.head()
# Out:
#    Unnamed: 0  Annual Returns on Investments in Year  \
# 0           0                                   2001
# 1           1                                   2002
# 2           2                                   2003
# 3           3                                   2004
# 4           4                                   2005
#
#    Annual Returns on Investments in S&P 500 (includes dividends)  \
# 0                                            -0.1185
# 1                                            -0.2197
# 2                                             0.2836
# 3                                             0.1074
# 4                                             0.0483
#
#    Annual Returns on Investments in 3-month T.Bill  \
# 0                                           0.0339
# 1                                           0.0160
# 2                                           0.0101
# 3                                           0.0137
# ...

# %%
corporate_tax=pd.read_csv('avg_cor_tax.csv')
corporate_tax.head()
# Out:
#         State  Average rates
# 0     Alabama         0.0650
# 1      Alaska         0.0534
# 2     Arizona         0.0490
# 3    Arkansas         0.0338
# 4  California         0.0884

# %%
income_tax=pd.read_csv('avg_indi_rates.csv')
income_tax.head()
# Out:
#         State  Average rates
# 0     Alabama       0.036667
# 1      Alaska       0.000000
# 2     Arizona       0.036500
# 3    Arkansas       0.038333
# 4  California       0.077500

# %%
income_tax['State'].unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'Florida', 'Georgia',
#        'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas',
#        'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts',
#        'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana',
#        'Nebraska', 'Neveda', 'New Hampshire', 'New Jersey', 'New Mexico',
#        'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma',
#        'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina',
#        'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont',
#        'Virginia', 'Washington', 'Washington, D.C.', 'West Virginia',
#        'Wisconsin', 'Wyoming'], dtype=object)

# %%
crime=pd.read_csv('crime.csv', index_col = 0)
crime.head()
# Out:
#        series   2010   2011   2012   2013   2014   2015   2016   2017   2018  \
# 1     Alabama  383.7  419.8  450.3  431.0  427.7  473.0  532.4  522.4  523.1
# 1      Alaska  635.3  610.1  604.1  638.7  635.5  730.8  804.6  856.7  891.7
# 1     Arizona  413.6  414.2  428.6  415.6  392.7  410.2  471.0  505.7  475.7
# 1    Arkansas  503.5  482.3  469.6  463.2  480.2  529.5  554.3  566.0  561.6
# 1  California  439.6  411.2  423.5  402.6  396.4  428.0  444.8  453.3  447.5
#
#     2019   2020
# 1  504.7  453.6
# 1  865.0  837.8
# 1  447.1  484.8
# 1  580.8  671.9
# 1  442.1  442.0

# %%
debt_and_avg_income=pd.read_csv('debtandavgincome.csv', index_col = 0)
debt_and_avg_income.head()
# Out:
#       county_name  fips state_name  Median Debt in Collections, All  \
# 0  Autauga County  1001    Alabama                           1905.0
# 1  Baldwin County  1003    Alabama                           2219.0
# 2  Barbour County  1005    Alabama                           1252.0
# 3     Bibb County  1007    Alabama                           1521.0
# 4   Blount County  1009    Alabama                           2013.0
#
#   Average household income
# 0                    75515
# 1                    80251
# 2                    47909
# 3                    58529
# 4                    60646

# %%
sales=pd.read_csv('sales.csv', index_col = 0)
sales.head()
# Out:
#         State  State Tax Rate  Avg. Local Tax Rate  Combined Rate  \
# 0     Alabama          0.0400             0.052386       0.092386
# 1      Alaska          0.0000             0.017603       0.017603
# 2     Arizona          0.0560             0.027962       0.083962
# 3    Arkansas          0.0650             0.029713       0.094713
# 4  California          0.0725             0.015691       0.088191
#
#    Max Local Tax Rate
# 0             0.07500
# 1             0.07500
# 2             0.05600
# 3             0.06125
# 4             0.02500

# %% [markdown]
# **Employed Status data**

# %%
CA_employed=pd.read_csv('CA_employed_new.csv', converters={'tract': lambda x: int(x)}, index_col = 0)
#CA_employed['tract']=CA_employed['tract'].apply(lambda x: str(x).zfill(11))

CA_employed.head()
# Out:
#         tract  year  16+_Pop  16+_Labor  16+_Employed
# 0  6001400100  2016   2652.0     1643.0        1568.0
# 1  6001400100  2017   2624.0     1608.0        1543.0
# 2  6001400100  2018   2676.0     1669.0        1578.0
# 3  6001400100  2019   2668.0     1680.0        1596.0
# 4  6001400100  2020   1346.0      870.0         854.0

# %%
FL_employed=pd.read_csv('FL_employed_new.csv', converters={'tract': lambda x: int(x)}, index_col = 0)
#FL_employed['tract']=FL_employed['tract'].apply(lambda x: str(x).zfill(11))

FL_employed.head()
# Out:
#          tract  year  16+_Pop  16+_Labor  16+_Employed
# 0  12001000200  2016  7228.00     3465.0        3012.0
# 1  12001000200  2017  6681.00     3151.0        2923.0
# 2  12001000200  2018  6534.00     3140.0        2913.0
# 3  12001000200  2019  7399.00     4067.0        3851.0
# 4  12001000200  2020  6360.75     3581.5        3356.5

# %%
SE_employed=pd.read_csv('SouthEast_employed_new.csv', converters={'tract': lambda x: int(x)}, index_col = 0)
#SE_employed['tract']=SE_employed['tract'].apply(lambda x: str(x).zfill(11))

SE_employed.head()
# Out:
#         tract  year  16+_Pop  16+_Labor  16+_Employed
# 0  1001020100  2016   1580.0     1027.0         984.0
# 1  1001020100  2017   1483.0      923.0         881.0
# 2  1001020100  2018   1562.0      966.0         931.0
# 3  1001020100  2019   1617.0      980.0         952.0
# 4  1001020100  2020   1558.0      852.0         834.0

# %%
South_employed=pd.read_csv('South_employed_new.csv', converters={'tract': lambda x: int(x)}, index_col = 0)
#South_employed['tract']=South_employed['tract'].apply(lambda x: str(x).zfill(11))

South_employed.head()
# Out:
#         tract  year  16+_Pop  16+_Labor  16+_Employed
# 0  1001020100  2016   1580.0     1027.0         984.0
# 1  1001020100  2017   1483.0      923.0         881.0
# 2  1001020100  2018   1562.0      966.0         931.0
# 3  1001020100  2019   1617.0      980.0         952.0
# 4  1001020100  2020   1558.0      852.0         834.0

# %%
SW_employed=pd.read_csv('SouthWest_employed_new.csv', converters={'tract': lambda x: int(x)}, index_col = 0)
#SW_employed['tract']=SW_employed['tract'].apply(lambda x: str(x).zfill(11))

SW_employed.head()
# Out:
#          tract  year  16+_Pop  16+_Labor  16+_Employed
# 0  35001000107  2016   2181.0     1263.0        1168.0
# 1  35001000107  2017   2149.0     1219.0        1144.0
# 2  35001000107  2018   2073.0     1194.0        1157.0
# 3  35001000107  2019   2106.0     1249.0        1214.0
# 4  35001000107  2020   2180.0     1269.0        1232.0

# %%
West_employed=pd.read_csv('Western_employed_new.csv', converters={'tract': lambda x: int(x)}, index_col = 0)
#West_employed['tract']=West_employed['tract'].apply(lambda x: str(x).zfill(11))

West_employed.head()
# Out:
#         tract  year  16+_Pop  16+_Labor  16+_Employed
# 0  4001942600  2016   1116.0      360.0         275.0
# 1  4001942600  2017   1148.0      379.0         311.0
# 2  4001942600  2018   1199.0      365.0         328.0
# 3  4001942600  2019   1334.0      429.0         372.0
# 4  4001942600  2020   1393.0      484.0         440.0

# %% [markdown]
# **Household Income data**

# %%
CA_income=pd.read_csv('CA_income_new.csv', converters={'tract': lambda x: int(x)}, index_col = 0)
#CA_income['tract']=CA_income['tract'].apply(lambda x: str(x).zfill(11))

CA_income.head()
# Out:
#         tract  year  median_income
# 0  6001400100  2016       177417.0
# 1  6001400100  2017       208393.0
# 2  6001400100  2018       200893.0
# 3  6001400100  2019       219861.0
# 4  6001400100  2020       214500.0

# %%
FL_income=pd.read_csv('FL_income_new.csv', converters={'tract': lambda x: int(x)}, index_col = 0)
#FL_income['tract']=FL_income['tract'].apply(lambda x: str(x).zfill(11))

FL_income.head()
# Out:
#          tract  year  median_income
# 0  12001000200  2016       31046.50
# 1  12001000200  2017       14232.00
# 2  12001000200  2018       18391.00
# 3  12001000200  2019       19241.00
# 4  12001000200  2020       21387.75

# %%
South_income=pd.read_csv('South_income_new.csv', converters={'tract': lambda x: int(x)}, index_col = 0)
#South_income['tract']=South_income['tract'].apply(lambda x: str(x).zfill(11))

South_income.head()
# Out:
#         tract  year  median_income
# 0  1001020100  2016        77813.0
# 1  1001020100  2017        55891.0
# 2  1001020100  2018        54664.5
# 3  1001020100  2019        57351.5
# 4  1001020100  2020        54933.0

# %%
SE_income=pd.read_csv('SouthEast_income_new.csv', converters={'tract': lambda x: int(x)}, index_col = 0)
#SE_income['tract']=SE_income['tract'].apply(lambda x: str(x).zfill(11))

SE_income.head()
# Out:
#         tract  year  median_income
# 0  1001020100  2016        77813.0
# 1  1001020100  2017        55891.0
# 2  1001020100  2018        54664.5
# 3  1001020100  2019        57351.5
# 4  1001020100  2020        54933.0

# %%
SW_income=pd.read_csv('SouthWest_income_new.csv', converters={'tract': lambda x: int(x)}, index_col = 0)
#SW_income['tract']=SW_income['tract'].apply(lambda x: str(x).zfill(11))
SW_income.head()
# Out:
#          tract  year  median_income
# 0  35001000107  2016        88916.5
# 1  35001000107  2017        85241.0
# 2  35001000107  2018        96250.0
# 3  35001000107  2019        93385.5
# 4  35001000107  2020        84297.0

# %%
West_income=pd.read_csv('Western_income_new.csv', converters={'tract': lambda x: int(x)}, index_col = 0)
#West_income['tract']=West_income['tract'].apply(lambda x: str(x).zfill(11))

West_income.head()
# Out:
#         tract  year  median_income
# 0  4001942600  2016        22371.5
# 1  4001942600  2017        22052.0
# 2  4001942600  2018        17979.0
# 3  4001942600  2019        18096.0
# 4  4001942600  2020        22164.0

# %% [markdown]
# **Occupancy Rate data**

# %%
FL_occupancy=pd.read_csv('FloridaOccupancyRate.csv', index_col = 0)
FL_occupancy=FL_occupancy.rename(columns={'Year':'year','Avg_RentActual':'Occupancy_rate'})
FL_occupancy.head()
# Out:
#   PROPERTY_ID  year  Occupancy_rate
# 0       101_1  2016       99.091667
# 1       101_1  2017       98.400000
# 2       101_1  2018       99.416667
# 3       101_1  2019       94.916667
# 4       101_1  2020       93.691667

# %%
FL_occupancy['PROPERTY_ID'].isnull().sum()
# Out:
# 0

# %%
FL_occupancy['year'].isnull().sum()
# Out:
# 0

# %%
FL_occupancy['Occupancy_rate'].isnull().sum()
# Out:
# 6412

# %%
FL_occupancy[FL_occupancy['Occupancy_rate'].isnull() == True]
# Out:
#       PROPERTY_ID  year  Occupancy_rate
# 147      101_1034  2016             NaN
# 148      101_1034  2017             NaN
# 149      101_1034  2018             NaN
# 150      101_1034  2019             NaN
# 151      101_1034  2020             NaN
# ...           ...   ...             ...
# 29696   57_940262  2018             NaN
# 29697   57_940262  2019             NaN
# 29698   57_940262  2020             NaN
# 29699   57_940262  2021             NaN
# 29700   57_940262  2022             NaN
#
# [6412 rows x 3 columns]

# %%
SoCal_occupancy=pd.read_csv('SoCalOccupancyRate.csv', index_col = 0)
SoCal_occupancy=SoCal_occupancy.rename(columns={'Year':'year','Avg_RentActual':'Occupancy_rate'})
SoCal_occupancy.head()
# Out:
#   PROPERTY_ID  year  Occupancy_rate
# 0        10_1  2016       96.800000
# 1        10_1  2017       95.558333
# 2        10_1  2018       96.733333
# 3        10_1  2019       93.883333
# 4        10_1  2020       97.575000

# %%
FL_occupancy.isnull().sum()
# Out:
# PROPERTY_ID          0
# year                 0
# Occupancy_rate    6412
# dtype: int64

# %%
SE_occupancy=pd.read_csv('SoutheastOccupancyRate.csv', index_col = 0)
SE_occupancy=SE_occupancy.rename(columns={'Year':'year','Avg_RentActual':'Occupancy_rate'})
SE_occupancy.head()
# Out:
#   PROPERTY_ID  year  Occupancy_rate
# 0     107_100  2016       95.750000
# 1     107_100  2017       95.166667
# 2     107_100  2018       91.100000
# 3     107_100  2019       95.308333
# 4     107_100  2020       90.575000

# %%
South_occupancy=pd.read_csv('SouthOccupancyRate.csv', index_col = 0)
South_occupancy=South_occupancy.rename(columns={'Year':'year','Avg_RentActual':'Occupancy_rate'})
South_occupancy.head()
# Out:
#   PROPERTY_ID  year  Occupancy_rate
# 0       104_1  2016       93.083333
# 1       104_1  2017       93.108333
# 2       104_1  2018       93.741667
# 3       104_1  2019       81.908333
# 4       104_1  2020       94.358333

# %%
SW_occupancy=pd.read_csv('SouthwestOccupancyRate.csv', index_col = 0)
SW_occupancy=SW_occupancy.rename(columns={'Year':'year','Avg_RentActual':'Occupancy_rate'})
SW_occupancy.head()
# Out:
#   PROPERTY_ID  year  Occupancy_rate
# 0       111_1  2016       95.883333
# 1       111_1  2017       95.450000
# 2       111_1  2018       91.066667
# 3       111_1  2019       92.866667
# 4       111_1  2020       94.875000

# %%
West_occupancy=pd.read_csv('WesternOccupancyRate.csv', index_col = 0)
West_occupancy=West_occupancy.rename(columns={'Year':'year','Avg_RentActual':'Occupancy_rate'})
West_occupancy.head()
# Out:
#   PROPERTY_ID  year  Occupancy_rate
# 0      109_10  2016       95.158333
# 1      109_10  2017       98.033333
# 2      109_10  2018       96.225000
# 3      109_10  2019       95.750000
# 4      109_10  2020       88.100000

# %% [markdown]
# **Population data**

# %%
CA_pop=pd.read_csv('CA_pop_new.csv', converters={'tract': lambda x: int(x)}, index_col = 0)
#CA_pop['tract']=CA_pop['tract'].apply(lambda x: str(x).zfill(11))
CA_pop.head()
# Out:
#         tract  year  population  white_pop  Black_pop  Native_pop  Asian_pop  \
# 0  6001400100  2016      3018.0     2193.0       92.0         0.0      499.0
# 1  6001400100  2017      2991.0     2132.0       84.0         0.0      491.0
# 2  6001400100  2018      3115.0     2122.0      128.0         0.0      599.0
# 3  6001400100  2019      3120.0     2394.0      107.0         0.0      398.0
# 4  6001400100  2020      1713.0     1240.0       79.0         1.0      249.0
#
#    Pacific_pop  male_population  female_population  0-19_pop  20-29_pop  \
# 0          0.0           1498.0             1520.0     478.0      115.0
# 1          0.0           1442.0             1549.0     503.0      140.0
# 2          0.0           1539.0             1576.0     572.0      162.0
# 3          0.0           1489.0             1631.0     573.0      121.0
# 4          0.0            969.0              744.0     409.0       85.0
#
#    30-39_pop  40-49_pop  50-59_pop  60-69_pop  70+_pop
# ...

# %%
SE_pop=pd.read_csv('SouthEast_pop_new.csv', converters={'tract': lambda x: int(x)}, index_col = 0)
#SE_pop['tract']=SE_pop['tract'].apply(lambda x: str(x).zfill(11))
SE_pop.head()
# Out:
#         tract  year  population  white_pop  Black_pop  Native_pop  Asian_pop  \
# 0  1001020100  2016      2010.0     1668.0      264.0         0.0        9.0
# 1  1001020100  2017      1845.0     1636.0       96.0         0.0       22.0
# 2  1001020100  2018      1923.0     1609.0      161.0         0.0       17.0
# 3  1001020100  2019      1993.0     1685.0      152.0         0.0        2.0
# 4  1001020100  2020      1941.0     1537.0      235.0         0.0       41.0
#
#    Pacific_pop  male_population  female_population  0-19_pop  20-29_pop  \
# 0         0.00            995.0             1015.0     507.0      263.0
# 1         0.00            899.0              946.0     436.0      220.0
# 2         0.00            929.0              994.0     471.0      203.0
# 3         0.00            907.0             1086.0     479.0      246.0
# 4         3.25            978.0              963.0     474.0      206.0
#
#    30-39_pop  40-49_pop  50-59_pop  60-69_pop  70+_pop
# ...

# %%
South_pop=pd.read_csv('South_pop_new.csv', converters={'tract': lambda x: int(x)}, index_col = 0)

#South_pop['tract']=South_pop['tract'].apply(lambda x: str(x).zfill(11))

South_pop.head()
# Out:
#         tract  year  population  white_pop  Black_pop  Native_pop  Asian_pop  \
# 0  1001020100  2016      2010.0     1668.0      264.0         0.0        9.0
# 1  1001020100  2017      1845.0     1636.0       96.0         0.0       22.0
# 2  1001020100  2018      1923.0     1609.0      161.0         0.0       17.0
# 3  1001020100  2019      1993.0     1685.0      152.0         0.0        2.0
# 4  1001020100  2020      1941.0     1537.0      235.0         0.0       41.0
#
#    Pacific_pop  male_population  female_population  0-19_pop  20-29_pop  \
# 0         0.00            995.0             1015.0     507.0      263.0
# 1         0.00            899.0              946.0     436.0      220.0
# 2         0.00            929.0              994.0     471.0      203.0
# 3         0.00            907.0             1086.0     479.0      246.0
# 4         3.25            978.0              963.0     474.0      206.0
#
#    30-39_pop  40-49_pop  50-59_pop  60-69_pop  70+_pop
# ...

# %%
FL_pop=pd.read_csv('FL_pop_new.csv', converters={'tract': lambda x: int(x)}, index_col = 0)
#FL_pop['tract']=FL_pop['tract'].apply(lambda x: str(x).zfill(11))
FL_pop.head()
# Out:
#          tract  year  population  white_pop  Black_pop  Native_pop  Asian_pop  \
# 0  12001000200  2016      7295.0    5666.00     1057.0        0.00      181.0
# 1  12001000200  2017      6834.0    5046.00     1277.0        0.00      225.0
# 2  12001000200  2018      6671.0    5009.00     1081.0        0.00      355.0
# 3  12001000200  2019      7557.0    5668.00     1369.0        0.00      361.0
# 4  12001000200  2020      6618.0    4734.25     1390.5        3.25      304.0
#
#    Pacific_pop  male_population  female_population  0-19_pop  20-29_pop  \
# 0         97.0           3456.0             3839.0   1408.00    4729.00
# 1         36.0           3096.0             3738.0   1266.00    4237.00
# 2         16.0           2853.0             3818.0   1251.00    4360.00
# 3         14.0           3311.0             4246.0   1593.00    4974.00
# 4         10.5           2955.5             3662.5   1409.75    4038.25
#
#    30-39_pop  40-49_pop  50-59_pop  60-69_pop  70+_pop
# ...

# %%
SW_pop=pd.read_csv('SouthWest_pop_new.csv', converters={'tract': lambda x: int(x)}, index_col = 0)
#SW_pop['tract']=SW_pop['tract'].apply(lambda x: str(x).zfill(11))
SW_pop.head()
# Out:
#          tract  year  population  white_pop  Black_pop  Native_pop  Asian_pop  \
# 0  35001000107  2016      2514.0     2296.0      129.0         0.0       18.0
# 1  35001000107  2017      2473.0     2202.0       96.0        68.0       23.0
# 2  35001000107  2018      2442.0     2202.0       76.0       126.0        3.0
# 3  35001000107  2019      2448.0     2150.0       73.0       148.0       28.0
# 4  35001000107  2020      2489.0     2243.0       53.0       101.0       27.0
#
#    Pacific_pop  male_population  female_population  0-19_pop  20-29_pop  \
# 0          0.0           1271.0             1243.0     453.0      159.0
# 1          0.0           1253.0             1220.0     423.0      188.0
# 2          0.0           1276.0             1166.0     443.0      225.0
# 3          0.0           1295.0             1153.0     465.0      250.0
# 4          0.0           1278.0             1211.0     409.0      304.0
#
#    30-39_pop  40-49_pop  50-59_pop  60-69_pop  70+_pop
# ...

# %%
West_pop=pd.read_csv('Western_pop_new.csv', converters={'tract': lambda x: int(x)}, index_col = 0)
#West_pop['tract']=West_pop['tract'].apply(lambda x: str(x).zfill(11))
West_pop
# Out:
#              tract  year  population  white_pop  Black_pop  Native_pop  \
# 0       4001942600  2016      1534.0        0.0        0.0      1520.0
# 1       4001942600  2017      1552.0        0.0        0.0      1540.0
# 2       4001942600  2018      1591.0        0.0        0.0      1586.0
# 3       4001942600  2019      1742.0        0.0        0.0      1737.0
# 4       4001942600  2020      1711.0       11.0        0.0      1707.0
# ...            ...   ...         ...        ...        ...         ...
# 42583  56045951300  2018      3814.0     3565.0        0.0        34.0
# 42584  56045951300  2019      3755.0     3718.0        0.0        10.0
# 42585  56045951300  2020      3666.0     3464.0        0.0        38.0
# 42586  56045951300  2021      3666.0     3464.0        0.0        38.0
# 42587  56045951300  2022      3666.0     3464.0        0.0        38.0
#
#        Asian_pop  Pacific_pop  male_population  female_population  0-19_pop  \
# ...

# %% [markdown]
# **Location data (Tract Level)**

# %%
# starbucks=pd.read_csv('starbucksMappedData.csv')
# starbucks.tract=starbucks.tract.astype(str)
# starbucks=starbucks.drop(columns=['Unnamed: 0','lon','lat','block'])
# starbucks=starbucks.reset_index()
# starbucks=starbucks.groupby(['tract']).count()
# starbucks=starbucks.rename(columns={'index': 'starbucks'})
# starbucks['join']=starbucks.index
# starbucks=starbucks.reset_index()
# starbucks

# %%
# hospitals=pd.read_csv('HospitalsMappedData.csv')
# hospitals=hospitals.drop(columns=['Unnamed: 0','lon','lat','block'])
# hospitals=hospitals.reset_index()
# hospitals=hospitals.groupby(['tract']).count()
# hospitals=hospitals.rename(columns={'index': 'hospitals'})
# hospitals['join']=hospitals.index
# hospitals=hospitals.reset_index()

# hospitals

# %%
# grocery=pd.read_csv('GroceryVistsMappedData.csv')
# grocery['grocery_vists']=grocery['Total Visits']
# grocery=grocery[['tract','grocery_vists']]
# grocery['join']=grocery['tract'].astype(str)
# grocery

# %% [markdown]
# **Location data (Zipcode Level)**

# %%
starbucks=pd.read_csv('starbucks_us_zip.csv', converters={'zipcode': lambda x: int(x)})
starbucks=starbucks.reset_index()
starbucks=starbucks.groupby(['zipcode']).count()
starbucks=starbucks.rename(columns={'index': 'starbucks'}).drop(columns=['lat','lon'])
starbucks['join']=starbucks.index
starbucks=starbucks.reset_index()
#starbucks['join']=starbucks['join'].apply(lambda x: str(x).zfill(5))

starbucks.head()
# Out:
#    zipcode  starbucks  join
# 0     1002          1  1002
# 1     1003          1  1003
# 2     1013          3  1013
# 3     1020          1  1020
# 4     1028          1  1028

# %%
hospitals=pd.read_csv('hospitals_us_zip.csv', converters={'Zipcode': lambda x: int(x)})
hospitals=hospitals.reset_index()
hospitals=hospitals.groupby(['Zipcode']).count()
hospitals=hospitals.rename(columns={'index': 'hospitals'}).drop(columns=['Longitude','Latitude'])
hospitals['join']=hospitals.index
hospitals=hospitals.reset_index()




#hospitals['join']=hospitals['join'].apply(lambda x: str(x).zfill(5))
hospitals.head()
# Out:
#    Zipcode  hospitals  join
# 0      605          1   605
# 1      613          1   613
# 2      614          1   614
# 3      623          1   623
# 4      631          1   631

# %%
grocery=pd.read_csv('grocery_us_zip.csv', converters={'zipcode': lambda x: int(x)})
grocery=grocery.reset_index()
grocery=grocery.groupby(['zipcode']).count()
grocery=grocery.rename(columns={'index': 'grocery_vists'}).drop(columns=['lat','lon'])
grocery['join']=grocery.index
grocery=grocery.reset_index()
#grocery['join']=grocery['join'].apply(lambda x: str(x).zfill(5))

grocery.head()
# Out:
#    zipcode  grocery_vists  name  visits   join
# 0    23857              1     1       1  23857
# 1    27012              7     7       7  27012
# 2    27017              1     1       1  27017
# 3    27021              3     3       3  27021
# 4    27023              5     5       5  27023

# %%
colleges=pd.read_csv('college_us_zip.csv', converters={'Zipcode': lambda x: int(x)})
colleges=colleges.reset_index()
colleges=colleges.groupby(['Zipcode']).count()
colleges=colleges.rename(columns={'index': 'colleges'}).drop(columns=['Longitude','Latitude'])
colleges['join']=colleges.index
colleges=colleges.reset_index()

#colleges['join']=colleges['join'].apply(lambda x: str(x).zfill(5))

colleges.head()
# Out:
#    Zipcode  colleges  join
# 0      602         2   602
# 1      603         3   603
# 2      604         1   604
# 3      605         1   605
# 4      612         2   612

# %%
food_stores=pd.read_csv('foodstores_us_zipcode.csv', converters={'Zipcode': lambda x: int(x)})
food_stores=food_stores.reset_index()
food_stores=food_stores.rename(columns={'Zip Code': 'Zipcode'})
food_stores=food_stores.groupby(['Zipcode']).count()
food_stores=food_stores.rename(columns={'Unnamed: 0': 'food_stores'}).drop(columns=['State','County','City'])
food_stores['join']=food_stores.index
food_stores=food_stores.reset_index()


food_stores.head()
# Out:
#    Zipcode  index  food_stores   join
# 0     6390      5            5   6390
# 1    10001     78           78  10001
# 2    10002    175          175  10002
# 3    10003     89           89  10003
# 4    10004     10           10  10004

# %%
banks=pd.read_csv('bank_us_zip.csv', converters={'Zipcode': lambda x: int(x)})
banks=banks.reset_index()
banks=banks.groupby(['Zipcode']).count()
banks=banks.rename(columns={'index': 'banks'}).drop(columns=['Longitude','Latitude'])
banks['join']=banks.index
banks=banks.reset_index()

#banks['join']=banks['join'].apply(lambda x: str(x).zfill(5))

banks.head()
# Out:
#    Zipcode  banks  join
# 0      802      2   802
# 1      909     67   909
# 2      917     27   917
# 3      918    235   918
# 4     1027     10  1027

# %%
public_school=pd.read_csv('publicschool_us_zip.csv', converters={'Zipcode': lambda x: int(x)})
public_school=public_school.reset_index()
public_school=public_school.groupby(['Zipcode']).count()
public_school=public_school.rename(columns={'index': 'public_school'}).drop(columns=['Longitude','Latitude'])
public_school['join']=public_school.index
public_school=public_school.reset_index()

#public_school['join']=public_school['join'].apply(lambda x: str(x).zfill(5))

public_school.head()
# Out:
#    Zipcode  public_school  join
# 0      601              4   601
# 1      602             11   602
# 2      603              6   603
# 3      604              1   604
# 4      605              4   605

# %%
private_school=pd.read_csv('privateschool_us_zip.csv', converters={'Zipcode': lambda x: int(x)})
private_school=private_school.reset_index()
private_school=private_school.groupby(['Zipcode']).count()
private_school=private_school.rename(columns={'index': 'private_school'}).drop(columns=['Longitude','Latitude'])
private_school['join']=private_school.index
private_school=private_school.reset_index()

#private_school['join']=private_school['join'].apply(lambda x: str(x).zfill(5))

private_school.head()
# Out:
#    Zipcode  private_school  join
# 0     1002               2  1002
# 1     1013               3  1013
# 2     1020               1  1020
# 3     1027               2  1027
# 4     1033               1  1033

# %%
house=pd.read_csv('Housing_Start_Ver2.csv')
house['year']=house['Date'].astype(str).str[-4:]
house['year']=house['year'].astype(int)
house.head()
# Out:
#        Date  Florida  Colorado  Texas  California  Ohio  Minnesota  Montana  \
# 0  1/1/1988     7532       587   2475       11581  1703       1119       35
# 1  2/1/1988     7904       823   2992       11486  1961       1524       40
# 2  3/1/1988     9858       870   3018       12104  2220       1840       37
# 3  4/1/1988     8937       853   2951       12201  2280       1782       46
# 4  5/1/1988     9748       792   2892       12598  2409       1723       44
#
#    Massachusetts  Arizonia  ...  Delaware  Hawaii  Iowa  Kansas  Missouri  \
# 0           1626      1902  ...       438     251   344     402      1145
# 1           1767      2062  ...       482     324   344     589      1299
# 2           2325      2087  ...       430     413   375     646      1491
# 3           1561      2000  ...       417     434   412     571      1277
# 4           1841      2108  ...       514     383   367     574      1413
#
#    Nebraska  Oregon  North Dakota  Wisconsin  year
# ...

# %% [markdown]
# **Group State Data Together**

# %%
frames = [florida, south, southeast, west, southwest, south_cali]

result = pd.concat(frames)
result=result.dropna(subset=['PROPERTY_ID'])
result.head()
# Out:
#   PROPERTY_ID  MARKETID   MARKET_NAME SUBMARKET_CODE    SUBMARKET_NAME  \
# 0  57_1345491        57  Jacksonville           29.0    Fleming Island
# 1     57_1937        57  Jacksonville           29.0    Fleming Island
# 2     57_1936        57  Jacksonville           29.0    Fleming Island
# 3     57_3062        57  Jacksonville           26.0          Callahan
# 4     57_1909        57  Jacksonville           24.0  Fernandina Beach
#
#   COUNTY_NAME                 PROPERTY_NAME         PROPERTY_PRIORNAMES  \
# 0        Clay   Station Fleming Island, The                Station, The
# 1        Clay   Cobblestone at Eagle Harbor  Vineyards at Eagle Harbour
# 2        Clay  Lighthouse at Fleming Island            Lighthouse Court
# 3      Nassau      Pine Terrace I, II & III                         NaN
# 4      Nassau           Pepper Tree Village                         NaN
#
#          PROPERTY_ADDRESS     PROPERTY_CITY  ... PROPERTY_FRACTUREDCONDO  \
# ...

# %%
#add state and county codes
result['tract_codes']=result['tract'].astype(str)
result['county']=result['tract_codes'].str[-9:-6]
result['state_code']=result['tract_codes'].str[-11:-9]
result=result.drop(columns=['tract_codes'])
result
# Out:
#      PROPERTY_ID  MARKETID                           MARKET_NAME  \
# 0     57_1345491        57                          Jacksonville
# 1        57_1937        57                          Jacksonville
# 2        57_1936        57                          Jacksonville
# 3        57_3062        57                          Jacksonville
# 4        57_1909        57                          Jacksonville
# ...          ...       ...                                   ...
# 8235      13_945        13  San Fernando Valley - Ventura County
# 8236      13_946        13  San Fernando Valley - Ventura County
# 8237      13_961        13  San Fernando Valley - Ventura County
# 8238      13_983        13  San Fernando Valley - Ventura County
# 8239      13_998        13  San Fernando Valley - Ventura County
#
#      SUBMARKET_CODE    SUBMARKET_NAME  COUNTY_NAME  \
# 0              29.0    Fleming Island         Clay
# 1              29.0    Fleming Island         Clay
# ...

# %%
result['tract'].value_counts()
# Out:
# 6037701902     50
# 4013113100     32
# 12011042501    31
# 49035114000    30
# 47037019502    30
#                ..
# 28071950100     1
# 12099000104     1
# 12099004206     1
# 13135050580     1
# 48113019037     1
# Name: tract, Length: 16750, dtype: int64

# %%
result['tract']=result['tract'].abs()
result['PROPERTY_ZIPCODE']=result['PROPERTY_ZIPCODE'].abs()
result['tract'].value_counts()
# Out:
# 6037701902     50
# 4013113100     32
# 12011042501    31
# 49035114000    30
# 47037019502    30
#                ..
# 28071950100     1
# 12099000104     1
# 12099004206     1
# 13135050580     1
# 48113019037     1
# Name: tract, Length: 16750, dtype: int64

# %%
#check
result['tract'].min()
# Out:
# 1003010200

# %%
#Drop military, student, affordable, and age restricted rentals
result = result[result.PROPERTY_MILITARYHOUSING != 'P']
result = result[result.PROPERTY_MILITARYHOUSING != 'A']

# %%
result = result[result.PROPERTY_STUDENTHOUSING != 'P']
result = result[result.PROPERTY_STUDENTHOUSING != 'A']

# %%
result = result[result.PROPERTY_AGERESTRICTED != 'P']
result = result[result.PROPERTY_AGERESTRICTED != 'A']

# %%
result = result[result.PROPERTY_AFFORDABLEHOUSING != 'P']
result = result[result.PROPERTY_AFFORDABLEHOUSING != 'A']

# %%
result
# Out:
#      PROPERTY_ID  MARKETID                           MARKET_NAME  \
# 0     57_1345491        57                          Jacksonville
# 1        57_1937        57                          Jacksonville
# 2        57_1936        57                          Jacksonville
# 5        57_1981        57                          Jacksonville
# 6        57_1908        57                          Jacksonville
# ...          ...       ...                                   ...
# 8235      13_945        13  San Fernando Valley - Ventura County
# 8236      13_946        13  San Fernando Valley - Ventura County
# 8237      13_961        13  San Fernando Valley - Ventura County
# 8238      13_983        13  San Fernando Valley - Ventura County
# 8239      13_998        13  San Fernando Valley - Ventura County
#
#      SUBMARKET_CODE    SUBMARKET_NAME  COUNTY_NAME  \
# 0              29.0    Fleming Island         Clay
# 1              29.0    Fleming Island         Clay
# ...

# %% [markdown]
# # Add Third-Party Data to Dataset

# %%
states = {
    "Alabama": "AL",
    "Alaska": "AK",
    "Arizona": "AZ",
    "Arkansas": "AR",
    "California": "CA",
    "Colorado": "CO",
    "Connecticut": "CT",
    "Delaware": "DE",
    "Florida": "FL",
    "Georgia": "GA",
    "Hawaii": "HI",
    "Idaho": "ID",
    "Illinois": "IL",
    "Indiana": "IN",
    "Iowa": "IA",
    "Kansas": "KS",
    "Kentucky": "KY",
    "Louisiana": "LA",
    "Maine": "ME",
    "Maryland": "MD",
    "Massachusetts": "MA",
    "Michigan": "MI",
    "Minnesota": "MN",
    "Mississippi": "MS",
    "Missouri": "MO",
    "Montana": "MT",
    "Nebraska": "NE",
    "Nevada": "NV",
    "Neveda": "NV",
    "New Hampshire": "NH",
    "New Jersey": "NJ",
    "New Mexico": "NM",
    "New York": "NY",
    "North Carolina": "NC",
    "North Dakota": "ND",
    "Ohio": "OH",
    "Oklahoma": "OK",
    "Oregon": "OR",
    "Pennsylvania": "PA",
    "Rhode Island": "RI",
    "South Carolina": "SC",
    "South Dakota": "SD",
    "Tennessee": "TN",
    "Texas": "TX",
    "Utah": "UT",
    "Vermont": "VT",
    "Virginia": "VA",
    "Washington": "WA",
    "West Virginia": "WV",
    "Wisconsin": "WI",
    "Wyoming": "WY",
    "District of Columbia": "DC",
    "Washington, D.C.": "DC",
    "American Samoa": "AS",
    "Guam": "GU",
    "Northern Mariana Islands": "MP",
    "Puerto Rico": "PR",
    "United States Minor Outlying Islands": "UM",
    "U.S. Virgin Islands": "VI",
}


result.head()
# Out:
#   PROPERTY_ID  MARKETID   MARKET_NAME SUBMARKET_CODE    SUBMARKET_NAME  \
# 0  57_1345491        57  Jacksonville           29.0    Fleming Island
# 1     57_1937        57  Jacksonville           29.0    Fleming Island
# 2     57_1936        57  Jacksonville           29.0    Fleming Island
# 5     57_1981        57  Jacksonville           24.0  Fernandina Beach
# 6     57_1908        57  Jacksonville           24.0  Fernandina Beach
#
#   COUNTY_NAME                 PROPERTY_NAME         PROPERTY_PRIORNAMES  \
# 0        Clay   Station Fleming Island, The                Station, The
# 1        Clay   Cobblestone at Eagle Harbor  Vineyards at Eagle Harbour
# 2        Clay  Lighthouse at Fleming Island            Lighthouse Court
# 5      Nassau                  Amelia Lakes                         NaN
# 6      Nassau         Marsh Cove & Somerset                    Somerset
#
#          PROPERTY_ADDRESS     PROPERTY_CITY  ... PROPERTY_SINGLEFAMILYRENTAL  \
# ...

# %% [markdown]
# **Area of each tract (In Sq meters)**

# %%
CA_area=pd.read_csv('CA_area.csv', converters={'tract': lambda x: int(x)})
CA_area=CA_area.rename(columns={"ALAND": "Tract Area"}).drop(CA_area.columns[[0,1,2,4]],axis=1)
CA_area.head()
# Out:
#         tract  Tract Area
# 0  6001400100   6945856.0
# 1  6001400200    586560.0
# 2  6001400300   1110840.0
# 3  6001400400    716138.0
# 4  6001400500    591424.0

# %%
FL_area=pd.read_csv('FL_area.csv', converters={'tract': lambda x: int(x)}).rename(columns={"ALAND": "Tract Area"})
FL_area=FL_area.drop(FL_area.columns[[0,1,2,4]],axis=1)
FL_area.head()
# Out:
#          tract    Tract Area
# 0  12001000200  7.407384e+07
# 1  12001000301  2.479034e+06
# 2  12001000302  3.819522e+06
# 3  12001000400  6.010490e+06
# 4  12001000500  3.917560e+06

# %%
South_area=pd.read_csv('South_area.csv', converters={'tract': lambda x: int(x)}).rename(columns={"ALAND": "Tract Area"})
South_area=South_area.drop(South_area.columns[[0,1,2,4]],axis=1)
#South_area['tract']=South_area['tract'].astype(np.int64)
South_area
# Out:
#             tract   Tract Area
# 0     13001950100  325861171.0
# 1     13001950200  114358199.0
# 2     13001950300  114358199.0
# 3     13001950400  388759782.0
# 4     13001950500  373034730.0
# ...           ...          ...
# 9766  47189030800  172943241.0
# 9767  47189030901   73003388.4
# 9768  47189030903   73003388.4
# 9769  47189030904  201617744.0
# 9770  47189031000  344402021.0
#
# [9771 rows x 2 columns]

# %%
SouthEast_area=pd.read_csv('SouthEast_area.csv', converters={'tract': lambda x: int(x)}).rename(columns={"ALAND": "Tract Area"})
SouthEast_area=SouthEast_area.drop(SouthEast_area.columns[[0,1,2,4]],axis=1)
SouthEast_area
# Out:
#             tract   Tract Area
# 0     13001950100  325861171.0
# 1     13001950200  114358199.0
# 2     13001950300  114358199.0
# 3     13001950400  388759782.0
# 4     13001950500  373034730.0
# ...           ...          ...
# 6443   1133965503  132818111.0
# 6444   1133965600  471340367.0
# 6445   1133965700   73807706.0
# 6446   1133965800  184501316.0
# 6447   1133965900  260691391.0
#
# [6448 rows x 2 columns]

# %%
SouthWest_area=pd.read_csv('SouthWest_area.csv', converters={'tract': lambda x: int(x)}).rename(columns={"ALAND": "Tract Area"})
SouthWest_area=SouthWest_area.drop(SouthWest_area.columns[[0,1,2,4]],axis=1)
SouthWest_area
# Out:
#             tract    Tract Area
# 0     35001000107  3.171004e+06
# 1     35001000108  1.297390e+06
# 2     35001000109  1.278746e+06
# 3     35001000110  1.293626e+06
# 4     35001000111  1.339721e+06
# ...           ...           ...
# 6805  48505950400  8.619587e+08
# 6806  48507950100  1.114210e+09
# 6807  48507950200  5.907750e+08
# 6808  48507950301  1.635811e+09
# 6809  48507950302  1.947262e+07
#
# [6810 rows x 2 columns]

# %%
West_area=pd.read_csv('Western_area.csv', converters={'tract': lambda x: int(x)}).rename(columns={"ALAND": "Tract Area"})
West_area=West_area.drop(West_area.columns[[0,1,2,4]],axis=1)
West_area
# Out:
#             tract    Tract Area
# 0     35001000107  3.171004e+06
# 1     35001000108  1.297390e+06
# 2     35001000109  1.278746e+06
# 3     35001000110  1.293626e+06
# 4     35001000111  1.339721e+06
# ...           ...           ...
# 6079  56043000200  5.780730e+09
# 6080  56043000301  1.993200e+06
# 6081  56043000302  1.542922e+07
# 6082  56045951100  6.100000e+09
# 6083  56045951300  1.108038e+08
#
# [6084 rows x 2 columns]

# %%
West_zip_area=pd.read_csv('Western_zipcode_area_new.csv', converters={'Zipcode': lambda x: int(x)})
West_zip_area=West_zip_area.drop(West_zip_area.columns[[0,3,4]],axis=1)
#West_zip_area['Zipcode']=West_zip_area['Zipcode'].apply(lambda x: str(x).zfill(5)).astype(str)
West_zip_area.head()
# Out:
#    Zipcode   Area
# 0    85003   1.85
# 1    85004   2.04
# 2    85006   3.90
# 3    85007   4.51
# 4    85008  10.47

# %%
West_zip_area.isnull().sum()
# Out:
# Zipcode    0
# Area       0
# dtype: int64

# %%
CA_zip_area=pd.read_csv('CA_zipcode_area_new.csv', converters={'Zipcode': lambda x: int(x)})
CA_zip_area=CA_zip_area.drop(CA_zip_area.columns[[0,3,4]],axis=1)
#CA_zip_area['Zipcode']=CA_zip_area['Zipcode'].apply(lambda x: str(x).zfill(5)).astype(str)
CA_zip_area.head()
# Out:
#    Zipcode  Area
# 0    90001  3.50
# 1    90002  3.06
# 2    90003  3.55
# 3    90004  3.05
# 4    90005  1.08

# %%
FL_zip_area=pd.read_csv('FL_zipcode_area_new.csv', converters={'Zipcode': lambda x: int(x)})
FL_zip_area=FL_zip_area.drop(FL_zip_area.columns[[0,3,4]],axis=1)

#FL_zip_area['Zipcode']=FL_zip_area['Zipcode'].apply(lambda x: str(x).zfill(5)).astype(str)
FL_zip_area.head()
# Out:
#    Zipcode    Area
# 0    32003   15.83
# 1    32008  138.09
# 2    32009   86.03
# 3    32011  173.49
# 4    32024  143.03

# %%
South_zip_area=pd.read_csv('South_zipcode_area_new.csv', converters={'Zipcode': lambda x: int(x)})
South_zip_area=South_zip_area.drop(South_zip_area.columns[[0,3,4]],axis=1)
#South_zip_area['Zipcode']=South_zip_area['Zipcode'].apply(lambda x: str(x).zfill(5)).astype(str)
South_zip_area.head()
# Out:
#    Zipcode   Area
# 0    30002   1.70
# 1    30004  57.39
# 2    30005  14.49
# 3    30008   9.45
# 4    30009   9.60

# %%
SouthEast_zip_area=pd.read_csv('SouthEast_zipcode_area_new.csv', converters={'Zipcode': lambda x: int(x)})
SouthEast_zip_area=SouthEast_zip_area.drop(SouthEast_zip_area.columns[[0,3,4]],axis=1)
#SouthEast_zip_area['Zipcode']=SouthEast_zip_area['Zipcode'].apply(lambda x: str(x).zfill(5)).astype(str)
SouthEast_zip_area.head()
# Out:
#    Zipcode   Area
# 0    30002   1.70
# 1    30004  57.39
# 2    30005  14.49
# 3    30008   9.45
# 4    30009   9.60

# %%
SouthWest_zip_area=pd.read_csv('SouthWest_zipcode_area_new.csv', converters={'Zipcode': lambda x: int(x)})
SouthWest_zip_area=SouthWest_zip_area.drop(SouthWest_zip_area.columns[[0,3,4]],axis=1)

#SouthWest_zip_area['Zipcode']=SouthWest_zip_area['Zipcode'].apply(lambda x: str(x).zfill(5))
#SouthWest_zip_area['Zipcode']=SouthWest_zip_area['Zipcode'].astype(str)
SouthWest_zip_area.head()
# Out:
#    Zipcode    Area
# 0    87001  120.12
# 1    87002  344.46
# 2    87004   56.55
# 3    87005   29.58
# 4    87006   57.47

# %%
result=result.drop_duplicates(subset=['PROPERTY_ID'], keep='first')
result.head()
# Out:
#   PROPERTY_ID  MARKETID   MARKET_NAME SUBMARKET_CODE    SUBMARKET_NAME  \
# 0  57_1345491        57  Jacksonville           29.0    Fleming Island
# 1     57_1937        57  Jacksonville           29.0    Fleming Island
# 2     57_1936        57  Jacksonville           29.0    Fleming Island
# 5     57_1981        57  Jacksonville           24.0  Fernandina Beach
# 6     57_1908        57  Jacksonville           24.0  Fernandina Beach
#
#   COUNTY_NAME                 PROPERTY_NAME         PROPERTY_PRIORNAMES  \
# 0        Clay   Station Fleming Island, The                Station, The
# 1        Clay   Cobblestone at Eagle Harbor  Vineyards at Eagle Harbour
# 2        Clay  Lighthouse at Fleming Island            Lighthouse Court
# 5      Nassau                  Amelia Lakes                         NaN
# 6      Nassau         Marsh Cove & Somerset                    Somerset
#
#          PROPERTY_ADDRESS     PROPERTY_CITY  ... PROPERTY_SINGLEFAMILYRENTAL  \
# ...

# %%
result.isnull().sum()
# Out:
# PROPERTY_ID                            0
# MARKETID                               0
# MARKET_NAME                            0
# SUBMARKET_CODE                        13
# SUBMARKET_NAME                        13
# COUNTY_NAME                            0
# PROPERTY_NAME                          0
# PROPERTY_PRIORNAMES                24008
# PROPERTY_ADDRESS                       0
# PROPERTY_CITY                          1
# PROPERTY_STATE                         0
# PROPERTY_ZIPCODE                       0
# lat                                    0
# lon                                    0
# PROPERTY_PHONE                      6292
# PROPERTY_UNITS                         0
# PROPERTY_SQFT                        272
# PROPERTY_ACRES                      4283
# PROPERTY_IMPRATING                  7210
# PROPERTY_LOCRATING                    75
# PROPERTY_STATUS                        9
# PROPERTY_DATE_PLANNED              30032
# PROPERTY_DATE_UNDERCONSTRUCTION    29549
# ...

# %%
result = result.drop(columns = ['Unnamed: 37'])
result.head()
# Out:
#   PROPERTY_ID  MARKETID   MARKET_NAME SUBMARKET_CODE    SUBMARKET_NAME  \
# 0  57_1345491        57  Jacksonville           29.0    Fleming Island
# 1     57_1937        57  Jacksonville           29.0    Fleming Island
# 2     57_1936        57  Jacksonville           29.0    Fleming Island
# 5     57_1981        57  Jacksonville           24.0  Fernandina Beach
# 6     57_1908        57  Jacksonville           24.0  Fernandina Beach
#
#   COUNTY_NAME                 PROPERTY_NAME         PROPERTY_PRIORNAMES  \
# 0        Clay   Station Fleming Island, The                Station, The
# 1        Clay   Cobblestone at Eagle Harbor  Vineyards at Eagle Harbour
# 2        Clay  Lighthouse at Fleming Island            Lighthouse Court
# 5      Nassau                  Amelia Lakes                         NaN
# 6      Nassau         Marsh Cove & Somerset                    Somerset
#
#          PROPERTY_ADDRESS     PROPERTY_CITY  ... PROPERTY_ADAPTIVEREUSE  \
# ...

# %%
#check
result['tract'].min()
# Out:
# 1003010500

# %%
frames = [CA_area, FL_area, South_area, SouthEast_area, SouthWest_area, West_area]
area = pd.concat(frames)
result['tract']=result['tract'].astype(int)
area['tract']=area['tract'].astype(int)
area['tract']=area['tract'].abs()
result['tract']=result['tract'].abs()

result=result.merge(area[['tract','Tract Area']],on=['tract'],how='left')
#result['tract']=result['tract'].abs()
result.head()
# Out:
#   PROPERTY_ID  MARKETID   MARKET_NAME SUBMARKET_CODE    SUBMARKET_NAME  \
# 0  57_1345491        57  Jacksonville           29.0    Fleming Island
# 1     57_1937        57  Jacksonville           29.0    Fleming Island
# 2     57_1936        57  Jacksonville           29.0    Fleming Island
# 3     57_1981        57  Jacksonville           24.0  Fernandina Beach
# 4     57_1908        57  Jacksonville           24.0  Fernandina Beach
#
#   COUNTY_NAME                 PROPERTY_NAME         PROPERTY_PRIORNAMES  \
# 0        Clay   Station Fleming Island, The                Station, The
# 1        Clay   Cobblestone at Eagle Harbor  Vineyards at Eagle Harbour
# 2        Clay  Lighthouse at Fleming Island            Lighthouse Court
# 3      Nassau                  Amelia Lakes                         NaN
# 4      Nassau         Marsh Cove & Somerset                    Somerset
#
#          PROPERTY_ADDRESS     PROPERTY_CITY  ... PROPERTY_SINGLEFAMILYRENTAL  \
# ...

# %%
#check
result['tract'].min()
# Out:
# 1769471

# %%
result['tract'].value_counts()
# Out:
# 182128457     36
# 1742734606    29
# 873859387     28
# 207620754     28
# 1742240606    24
#               ..
# 1115040211     1
# 2095329744     1
# 781873188      1
# 281546792      1
# 785895586      1
# Name: tract, Length: 14103, dtype: int64

# %%
result['tract']=result['tract'].abs()

# %%
result['tract'].value_counts()
# Out:
# 182128457     36
# 1742734606    29
# 873859387     28
# 207620754     28
# 1742240606    24
#               ..
# 1115040211     1
# 2095329744     1
# 781873188      1
# 281546792      1
# 785895586      1
# Name: tract, Length: 14103, dtype: int64

# %%
frames = [CA_zip_area, FL_zip_area, South_zip_area, SouthEast_zip_area, SouthWest_zip_area, West_zip_area]
area_zip = pd.concat(frames)
area_zip['Zipcode']=area_zip['Zipcode'].astype(int)
result['PROPERTY_ZIPCODE']=result['PROPERTY_ZIPCODE'].astype(int)
area_zip['Zipcode']=area_zip['Zipcode']
result=result.merge(area_zip[['Zipcode','Area']],left_on='PROPERTY_ZIPCODE',right_on='Zipcode',how='left')

result
# Out:
#       PROPERTY_ID  MARKETID                           MARKET_NAME  \
# 0      57_1345491        57                          Jacksonville
# 1         57_1937        57                          Jacksonville
# 2         57_1936        57                          Jacksonville
# 3         57_1981        57                          Jacksonville
# 4         57_1908        57                          Jacksonville
# ...           ...       ...                                   ...
# 43956      13_945        13  San Fernando Valley - Ventura County
# 43957      13_946        13  San Fernando Valley - Ventura County
# 43958      13_961        13  San Fernando Valley - Ventura County
# 43959      13_983        13  San Fernando Valley - Ventura County
# 43960      13_998        13  San Fernando Valley - Ventura County
#
#       SUBMARKET_CODE    SUBMARKET_NAME  COUNTY_NAME  \
# 0               29.0    Fleming Island         Clay
# 1               29.0    Fleming Island         Clay
# ...

# %%
result.isnull().sum()
# Out:
# PROPERTY_ID                            0
# MARKETID                               0
# MARKET_NAME                            0
# SUBMARKET_CODE                        17
# SUBMARKET_NAME                        17
# COUNTY_NAME                            0
# PROPERTY_NAME                          0
# PROPERTY_PRIORNAMES                28540
# PROPERTY_ADDRESS                       0
# PROPERTY_CITY                          1
# PROPERTY_STATE                         0
# PROPERTY_ZIPCODE                       0
# lat                                    0
# lon                                    0
# PROPERTY_PHONE                      7514
# PROPERTY_UNITS                         0
# PROPERTY_SQFT                        309
# PROPERTY_ACRES                      5304
# PROPERTY_IMPRATING                  8562
# PROPERTY_LOCRATING                    92
# PROPERTY_STATUS                        9
# PROPERTY_DATE_PLANNED              36481
# PROPERTY_DATE_UNDERCONSTRUCTION    35896
# ...

# %%
sales['State'] = sales['State'].map(states) 
#sales=sales.drop(sales.columns[0],axis=1)
sales=sales.rename(columns={"State": "PROPERTY_STATE"})
sales
result=result.merge(sales,on='PROPERTY_STATE',how='left')
result
# Out:
#       PROPERTY_ID  MARKETID                           MARKET_NAME  \
# 0      57_1345491        57                          Jacksonville
# 1         57_1937        57                          Jacksonville
# 2         57_1936        57                          Jacksonville
# 3         57_1981        57                          Jacksonville
# 4         57_1908        57                          Jacksonville
# ...           ...       ...                                   ...
# 43956      13_945        13  San Fernando Valley - Ventura County
# 43957      13_946        13  San Fernando Valley - Ventura County
# 43958      13_961        13  San Fernando Valley - Ventura County
# 43959      13_983        13  San Fernando Valley - Ventura County
# 43960      13_998        13  San Fernando Valley - Ventura County
#
#       SUBMARKET_CODE    SUBMARKET_NAME  COUNTY_NAME  \
# 0               29.0    Fleming Island         Clay
# 1               29.0    Fleming Island         Clay
# ...

# %%
result['Max Local Tax Rate'].isnull().sum()
# Out:
# 0

# %%
corporate_tax['State'] = corporate_tax['State'].map(states) 
#corporate_tax=corporate_tax.drop(corporate_tax.columns[0],axis=1)
corporate_tax=corporate_tax.rename(columns={"State": "PROPERTY_STATE",'Average rates':'corporate_tax'})
result=result.merge(corporate_tax,on='PROPERTY_STATE',how='left')
result
# Out:
#       PROPERTY_ID  MARKETID                           MARKET_NAME  \
# 0      57_1345491        57                          Jacksonville
# 1         57_1937        57                          Jacksonville
# 2         57_1936        57                          Jacksonville
# 3         57_1981        57                          Jacksonville
# 4         57_1908        57                          Jacksonville
# ...           ...       ...                                   ...
# 43956      13_945        13  San Fernando Valley - Ventura County
# 43957      13_946        13  San Fernando Valley - Ventura County
# 43958      13_961        13  San Fernando Valley - Ventura County
# 43959      13_983        13  San Fernando Valley - Ventura County
# 43960      13_998        13  San Fernando Valley - Ventura County
#
#       SUBMARKET_CODE    SUBMARKET_NAME  COUNTY_NAME  \
# 0               29.0    Fleming Island         Clay
# 1               29.0    Fleming Island         Clay
# ...

# %%
income_tax['State'] = income_tax['State'].map(states) 
#income_tax=income_tax.drop(income_tax.columns[0],axis=1)
income_tax=income_tax.rename(columns={"State": "PROPERTY_STATE",'Average rates':'income_tax'})
result=result.merge(income_tax,on='PROPERTY_STATE',how='left')
result.head()
# Out:
#   PROPERTY_ID  MARKETID   MARKET_NAME SUBMARKET_CODE    SUBMARKET_NAME  \
# 0  57_1345491        57  Jacksonville           29.0    Fleming Island
# 1     57_1937        57  Jacksonville           29.0    Fleming Island
# 2     57_1936        57  Jacksonville           29.0    Fleming Island
# 3     57_1981        57  Jacksonville           24.0  Fernandina Beach
# 4     57_1908        57  Jacksonville           24.0  Fernandina Beach
#
#   COUNTY_NAME                 PROPERTY_NAME         PROPERTY_PRIORNAMES  \
# 0        Clay   Station Fleming Island, The                Station, The
# 1        Clay   Cobblestone at Eagle Harbor  Vineyards at Eagle Harbour
# 2        Clay  Lighthouse at Fleming Island            Lighthouse Court
# 3      Nassau                  Amelia Lakes                         NaN
# 4      Nassau         Marsh Cove & Somerset                    Somerset
#
#          PROPERTY_ADDRESS     PROPERTY_CITY  ... state_code  Tract Area  \
# ...

# %%
result['income_tax'].isnull().sum()
# Out:
# 0

# %%
 starbucks['join']=starbucks['join'].astype(int)
# starbucks=starbucks[starbucks["join"].str.contains('a')==False]
# starbucks=starbucks[starbucks["join"].str.contains('N')==False]
# starbucks=starbucks[starbucks["join"].str.contains('n')==False]
# starbucks=starbucks[starbucks["join"].str.contains('o')==False]
# starbucks['join']=starbucks['join'].astype(str)
starbucks['join']=starbucks[starbucks['join'].notna()]

starbucks['PROPERTY_ZIPCODE']=starbucks['join']
starbucks=starbucks[['PROPERTY_ZIPCODE','starbucks']]
starbucks['PROPERTY_ZIPCODE']=starbucks['PROPERTY_ZIPCODE']
result=result.merge(starbucks,on='PROPERTY_ZIPCODE',how='left')
result
# Out:
#       PROPERTY_ID  MARKETID                           MARKET_NAME  \
# 0      57_1345491        57                          Jacksonville
# 1         57_1937        57                          Jacksonville
# 2         57_1936        57                          Jacksonville
# 3         57_1981        57                          Jacksonville
# 4         57_1908        57                          Jacksonville
# ...           ...       ...                                   ...
# 43956      13_945        13  San Fernando Valley - Ventura County
# 43957      13_946        13  San Fernando Valley - Ventura County
# 43958      13_961        13  San Fernando Valley - Ventura County
# 43959      13_983        13  San Fernando Valley - Ventura County
# 43960      13_998        13  San Fernando Valley - Ventura County
#
#       SUBMARKET_CODE    SUBMARKET_NAME  COUNTY_NAME  \
# 0               29.0    Fleming Island         Clay
# 1               29.0    Fleming Island         Clay
# ...

# %%
display(result[result.starbucks.notna()])
display(result)
# Out:
#       PROPERTY_ID  MARKETID                           MARKET_NAME  \
# 0      57_1345491        57                          Jacksonville
# 1         57_1937        57                          Jacksonville
# 2         57_1936        57                          Jacksonville
# 3         57_1981        57                          Jacksonville
# 4         57_1908        57                          Jacksonville
# ...           ...       ...                                   ...
# 43950   13_674892        13  San Fernando Valley - Ventura County
# 43951      13_905        13  San Fernando Valley - Ventura County
# 43958      13_961        13  San Fernando Valley - Ventura County
# 43959      13_983        13  San Fernando Valley - Ventura County
# 43960      13_998        13  San Fernando Valley - Ventura County
#
#       SUBMARKET_CODE    SUBMARKET_NAME  COUNTY_NAME  \
# 0               29.0    Fleming Island         Clay
# 1               29.0    Fleming Island         Clay
# ...

# %%
hospitals['join']=hospitals['join'].astype(int)

# hospitals=hospitals[hospitals["join"].str.contains('a')==False]
# hospitals=hospitals[hospitals["join"].str.contains('N')==False]
# hospitals=hospitals[hospitals["join"].str.contains('n')==False]
# hospitals=hospitals[hospitals["join"].str.contains('o')==False]
# hospitals['join']=hospitals['join'].astype(str)
hospitals['join']=hospitals[hospitals['join'].notna()]

hospitals['PROPERTY_ZIPCODE']=hospitals['join']
hospitals=hospitals[['PROPERTY_ZIPCODE','hospitals']]
result=result.merge(hospitals,on='PROPERTY_ZIPCODE',how='left')
result
# Out:
#       PROPERTY_ID  MARKETID                           MARKET_NAME  \
# 0      57_1345491        57                          Jacksonville
# 1         57_1937        57                          Jacksonville
# 2         57_1936        57                          Jacksonville
# 3         57_1981        57                          Jacksonville
# 4         57_1908        57                          Jacksonville
# ...           ...       ...                                   ...
# 43956      13_945        13  San Fernando Valley - Ventura County
# 43957      13_946        13  San Fernando Valley - Ventura County
# 43958      13_961        13  San Fernando Valley - Ventura County
# 43959      13_983        13  San Fernando Valley - Ventura County
# 43960      13_998        13  San Fernando Valley - Ventura County
#
#       SUBMARKET_CODE    SUBMARKET_NAME  COUNTY_NAME  \
# 0               29.0    Fleming Island         Clay
# 1               29.0    Fleming Island         Clay
# ...

# %%
display(result[result.hospitals.notna()])
display(result)
# Out:
#       PROPERTY_ID  MARKETID                           MARKET_NAME  \
# 3         57_1981        57                          Jacksonville
# 4         57_1908        57                          Jacksonville
# 5       57_474156        57                          Jacksonville
# 6      57_1110948        57                          Jacksonville
# 7         57_1959        57                          Jacksonville
# ...           ...       ...                                   ...
# 43950   13_674892        13  San Fernando Valley - Ventura County
# 43951      13_905        13  San Fernando Valley - Ventura County
# 43958      13_961        13  San Fernando Valley - Ventura County
# 43959      13_983        13  San Fernando Valley - Ventura County
# 43960      13_998        13  San Fernando Valley - Ventura County
#
#       SUBMARKET_CODE      SUBMARKET_NAME  COUNTY_NAME  \
# 3               24.0    Fernandina Beach       Nassau
# 4               24.0    Fernandina Beach       Nassau
# ...

# %%
 colleges['join']=colleges['join'].astype(int)
# colleges=colleges[colleges["join"].str.contains('a')==False]
# colleges=colleges[colleges["join"].str.contains('N')==False]
# colleges=colleges[colleges["join"].str.contains('n')==False]
# colleges=colleges[colleges["join"].str.contains('o')==False]
# colleges['join']=colleges['join'].astype(str)
colleges['join']=colleges[colleges['join'].notna()]

colleges['PROPERTY_ZIPCODE']=colleges['join']
colleges=colleges[['PROPERTY_ZIPCODE','colleges']]

result=result.merge(colleges,on='PROPERTY_ZIPCODE',how='left')
result
# Out:
#       PROPERTY_ID  MARKETID                           MARKET_NAME  \
# 0      57_1345491        57                          Jacksonville
# 1         57_1937        57                          Jacksonville
# 2         57_1936        57                          Jacksonville
# 3         57_1981        57                          Jacksonville
# 4         57_1908        57                          Jacksonville
# ...           ...       ...                                   ...
# 43956      13_945        13  San Fernando Valley - Ventura County
# 43957      13_946        13  San Fernando Valley - Ventura County
# 43958      13_961        13  San Fernando Valley - Ventura County
# 43959      13_983        13  San Fernando Valley - Ventura County
# 43960      13_998        13  San Fernando Valley - Ventura County
#
#       SUBMARKET_CODE    SUBMARKET_NAME  COUNTY_NAME  \
# 0               29.0    Fleming Island         Clay
# 1               29.0    Fleming Island         Clay
# ...

# %%
# food_stores['join']=food_stores['join'].astype(str)
# food_stores=food_stores[food_stores["join"].str.contains('a')==False]
# food_stores=food_stores[food_stores["join"].str.contains('N')==False]
# food_stores=food_stores[food_stores["join"].str.contains('n')==False]
# food_stores=food_stores[food_stores["join"].str.contains('o')==False]
# food_stores['join']=food_stores['join'].astype(str)
# food_stores['PROPERTY_ZIPCODE']=food_stores['join']
# food_stores=food_stores[['PROPERTY_ZIPCODE','food_stores']]
# result=result.merge(food_stores,on='PROPERTY_ZIPCODE',how='left')
# result

# %%
result['PROPERTY_ZIPCODE'].describe()
# Out:
# count    43961.000000
# mean     58017.729306
# std      25524.741917
# min      26971.000000
# 25%      31419.000000
# 50%      72034.000000
# 75%      80221.000000
# max      95625.000000
# Name: PROPERTY_ZIPCODE, dtype: float64

# %%
banks['join']=banks['join'].astype(int)
# banks=banks[banks["join"].str.contains('a')==False]
# banks=banks[banks["join"].str.contains('N')==False]
# banks=banks[banks["join"].str.contains('n')==False]
# banks=banks[banks["join"].str.contains('o')==False]
# banks['join']=banks['join'].astype(str)
banks['join']=banks[banks['join'].notna()]

banks['PROPERTY_ZIPCODE']=banks['join']
banks=banks[['PROPERTY_ZIPCODE','banks']]
result=result.merge(banks,on='PROPERTY_ZIPCODE',how='left')
result
# Out:
#       PROPERTY_ID  MARKETID                           MARKET_NAME  \
# 0      57_1345491        57                          Jacksonville
# 1         57_1937        57                          Jacksonville
# 2         57_1936        57                          Jacksonville
# 3         57_1981        57                          Jacksonville
# 4         57_1908        57                          Jacksonville
# ...           ...       ...                                   ...
# 43956      13_945        13  San Fernando Valley - Ventura County
# 43957      13_946        13  San Fernando Valley - Ventura County
# 43958      13_961        13  San Fernando Valley - Ventura County
# 43959      13_983        13  San Fernando Valley - Ventura County
# 43960      13_998        13  San Fernando Valley - Ventura County
#
#       SUBMARKET_CODE    SUBMARKET_NAME  COUNTY_NAME  \
# 0               29.0    Fleming Island         Clay
# 1               29.0    Fleming Island         Clay
# ...

# %%
public_school['join']=public_school['join'].astype(int)
# public_school=public_school[public_school["join"].str.contains('a')==False]
# public_school=public_school[public_school["join"].str.contains('N')==False]
# public_school=public_school[public_school["join"].str.contains('n')==False]
# public_school=public_school[public_school["join"].str.contains('o')==False]
# public_school['join']=public_school['join'].astype(str)

public_school['join']=public_school[public_school['join'].notna()]


public_school['PROPERTY_ZIPCODE']=public_school['join']
public_school=public_school[['PROPERTY_ZIPCODE','public_school']]
result=result.merge(public_school,on='PROPERTY_ZIPCODE',how='left')
result
# Out:
#       PROPERTY_ID  MARKETID                           MARKET_NAME  \
# 0      57_1345491        57                          Jacksonville
# 1         57_1937        57                          Jacksonville
# 2         57_1936        57                          Jacksonville
# 3         57_1981        57                          Jacksonville
# 4         57_1908        57                          Jacksonville
# ...           ...       ...                                   ...
# 43956      13_945        13  San Fernando Valley - Ventura County
# 43957      13_946        13  San Fernando Valley - Ventura County
# 43958      13_961        13  San Fernando Valley - Ventura County
# 43959      13_983        13  San Fernando Valley - Ventura County
# 43960      13_998        13  San Fernando Valley - Ventura County
#
#       SUBMARKET_CODE    SUBMARKET_NAME  COUNTY_NAME  \
# 0               29.0    Fleming Island         Clay
# 1               29.0    Fleming Island         Clay
# ...

# %%
private_school['join']=private_school['join'].astype(int)
# private_school=private_school[private_school["join"].str.contains('a')==False]
# private_school=private_school[private_school["join"].str.contains('N')==False]
# private_school=private_school[private_school["join"].str.contains('n')==False]
# private_school=private_school[private_school["join"].str.contains('o')==False]
# private_school['join']=private_school['join'].astype(str)

private_school['join']=private_school[private_school['join'].notna()]


private_school['PROPERTY_ZIPCODE']=private_school['join']
private_school=private_school[['PROPERTY_ZIPCODE','private_school']]
result=result.merge(private_school,on='PROPERTY_ZIPCODE',how='left')
result
# Out:
#       PROPERTY_ID  MARKETID                           MARKET_NAME  \
# 0      57_1345491        57                          Jacksonville
# 1         57_1937        57                          Jacksonville
# 2         57_1936        57                          Jacksonville
# 3         57_1981        57                          Jacksonville
# 4         57_1908        57                          Jacksonville
# ...           ...       ...                                   ...
# 43956      13_945        13  San Fernando Valley - Ventura County
# 43957      13_946        13  San Fernando Valley - Ventura County
# 43958      13_961        13  San Fernando Valley - Ventura County
# 43959      13_983        13  San Fernando Valley - Ventura County
# 43960      13_998        13  San Fernando Valley - Ventura County
#
#       SUBMARKET_CODE    SUBMARKET_NAME  COUNTY_NAME  \
# 0               29.0    Fleming Island         Clay
# 1               29.0    Fleming Island         Clay
# ...

# %%
grocery['join']=grocery['join'].astype(int)

# grocery=grocery[grocery["join"].str.contains('a')==False]
# grocery=grocery[grocery["join"].str.contains('N')==False]
# grocery=grocery[grocery["join"].str.contains('n')==False]
# grocery=grocery[grocery["join"].str.contains('o')==False]
# grocery['join']=grocery['join'].astype(str)

grocery['join']=grocery[grocery['join'].notna()]
grocery['PROPERTY_ZIPCODE']=grocery['join']
grocery=grocery[['PROPERTY_ZIPCODE','grocery_vists']]

result=result.merge(grocery,on='PROPERTY_ZIPCODE',how='left')
result
# Out:
#       PROPERTY_ID  MARKETID                           MARKET_NAME  \
# 0      57_1345491        57                          Jacksonville
# 1         57_1937        57                          Jacksonville
# 2         57_1936        57                          Jacksonville
# 3         57_1981        57                          Jacksonville
# 4         57_1908        57                          Jacksonville
# ...           ...       ...                                   ...
# 43956      13_945        13  San Fernando Valley - Ventura County
# 43957      13_946        13  San Fernando Valley - Ventura County
# 43958      13_961        13  San Fernando Valley - Ventura County
# 43959      13_983        13  San Fernando Valley - Ventura County
# 43960      13_998        13  San Fernando Valley - Ventura County
#
#       SUBMARKET_CODE    SUBMARKET_NAME  COUNTY_NAME  \
# 0               29.0    Fleming Island         Clay
# 1               29.0    Fleming Island         Clay
# ...

# %%
result[result['grocery_vists'].isna()]
# Out:
#       PROPERTY_ID  MARKETID                           MARKET_NAME  \
# 189       57_1250        57                          Jacksonville
# 190       57_1249        57                          Jacksonville
# 191    57_1267958        57                          Jacksonville
# 192       57_1371        57                          Jacksonville
# 193       57_1553        57                          Jacksonville
# ...           ...       ...                                   ...
# 43956      13_945        13  San Fernando Valley - Ventura County
# 43957      13_946        13  San Fernando Valley - Ventura County
# 43958      13_961        13  San Fernando Valley - Ventura County
# 43959      13_983        13  San Fernando Valley - Ventura County
# 43960      13_998        13  San Fernando Valley - Ventura County
#
#       SUBMARKET_CODE           SUBMARKET_NAME  COUNTY_NAME  \
# 189              1.0  Jacksonville - Downtown        Duval
# ...

# %%
#add join table to map FIPS code to zip code
fips=pd.read_excel('fips_to_zip_new.xlsx', index_col = 0)
fips.head()
# Out:
#      ZIP      COUNTYNAME STATE  STCOUNTYFP CLASSFP
# 0  36003  Autauga County    AL        1001      H1
# 1  36006  Autauga County    AL        1001      H1
# 2  36067  Autauga County    AL        1001      H1
# 3  36066  Autauga County    AL        1001      H1
# 4  36703  Autauga County    AL        1001      H1

# %%
# fips=fips.merge(debt_and_avg_income,left_on='STCOUNTYFP',right_on='fips',how='left')
# fips['PROPERTY_ZIPCODE']=fips['ZIP']
# fips['median_debt']=fips['Median Debt in Collections, All']
# fips=fips.dropna(subset=['Average household income'])
# #debt_income=fips[['PROPERTY_ZIPCODE','Average household income','median_debt']]
# fips

# %%
fips=fips.merge(debt_and_avg_income,left_on='STCOUNTYFP',right_on='fips',how='left')
fips['PROPERTY_ZIPCODE']=fips['ZIP']
fips['median_debt']=fips['Median Debt in Collections, All']
fips=fips.dropna(subset=['Average household income'])
debt_income=fips[['PROPERTY_ZIPCODE','Average household income','median_debt']]
debt_income
# Out:
#        PROPERTY_ZIPCODE Average household income  median_debt
# 0                 36003                    75515  1905.000000
# 1                 36006                    75515  1905.000000
# 2                 36067                    75515  1905.000000
# 3                 36066                    75515  1905.000000
# 4                 36703                    75515  1905.000000
# ...                 ...                      ...          ...
# 52566             82729                    68181  1835.121616
# 52567             82730                    68181  1835.121616
# 52568             82701                    68181  1835.121616
# 52569             82723                    68181  1835.121616
# 52570             82715                    68181  1835.121616
#
# [52545 rows x 3 columns]

# %%
debt_income=debt_income.rename(columns={'Average household income':'avg_house_income'})
debt_income=debt_income[debt_income["avg_house_income"].str.contains('a')==False]
debt_income['avg_house_income']=debt_income['avg_house_income'].astype(int)
debt_income['PROPERTY_ZIPCODE']=debt_income['PROPERTY_ZIPCODE'].astype(int)
result=result.merge(debt_income,on='PROPERTY_ZIPCODE',how='left')
result
# Out:
#       PROPERTY_ID  MARKETID                           MARKET_NAME  \
# 0      57_1345491        57                          Jacksonville
# 1         57_1937        57                          Jacksonville
# 2         57_1936        57                          Jacksonville
# 3         57_1981        57                          Jacksonville
# 4         57_1908        57                          Jacksonville
# ...           ...       ...                                   ...
# 55596      13_946        13  San Fernando Valley - Ventura County
# 55597      13_961        13  San Fernando Valley - Ventura County
# 55598      13_983        13  San Fernando Valley - Ventura County
# 55599      13_998        13  San Fernando Valley - Ventura County
# 55600      13_998        13  San Fernando Valley - Ventura County
#
#       SUBMARKET_CODE    SUBMARKET_NAME  COUNTY_NAME  \
# 0               29.0    Fleming Island         Clay
# 1               29.0    Fleming Island         Clay
# ...

# %%
result['avg_house_income'].isna().sum()
# Out:
# 20

# %%
result = result.dropna(subset=['avg_house_income'])

# %%
#Turn cross sectional data into panel data by adding years
z=[]
for x in range(len(result)):
    z.append(2016)
for x in range(len(result)):
    z.append(2017)
for x in range(len(result)):
    z.append(2018)
for x in range(len(result)):
    z.append(2019)
for x in range(len(result)):
    z.append(2020)
for x in range(len(result)):
    z.append(2021)
for x in range(len(result)):
    z.append(2022)
result=pd.concat([result]*7)
result['year']=z
result
# Out:
#       PROPERTY_ID  MARKETID                           MARKET_NAME  \
# 0      57_1345491        57                          Jacksonville
# 1         57_1937        57                          Jacksonville
# 2         57_1936        57                          Jacksonville
# 3         57_1981        57                          Jacksonville
# 4         57_1908        57                          Jacksonville
# ...           ...       ...                                   ...
# 55596      13_946        13  San Fernando Valley - Ventura County
# 55597      13_961        13  San Fernando Valley - Ventura County
# 55598      13_983        13  San Fernando Valley - Ventura County
# 55599      13_998        13  San Fernando Valley - Ventura County
# 55600      13_998        13  San Fernando Valley - Ventura County
#
#       SUBMARKET_CODE    SUBMARKET_NAME  COUNTY_NAME  \
# 0               29.0    Fleming Island         Clay
# 1               29.0    Fleming Island         Clay
# ...

# %%
cols=list(result.columns)
cols.remove('year')
cols.insert(1,'year')
result=result[cols]
result
# Out:
#       PROPERTY_ID  year  MARKETID                           MARKET_NAME  \
# 0      57_1345491  2016        57                          Jacksonville
# 1         57_1937  2016        57                          Jacksonville
# 2         57_1936  2016        57                          Jacksonville
# 3         57_1981  2016        57                          Jacksonville
# 4         57_1908  2016        57                          Jacksonville
# ...           ...   ...       ...                                   ...
# 55596      13_946  2022        13  San Fernando Valley - Ventura County
# 55597      13_961  2022        13  San Fernando Valley - Ventura County
# 55598      13_983  2022        13  San Fernando Valley - Ventura County
# 55599      13_998  2022        13  San Fernando Valley - Ventura County
# 55600      13_998  2022        13  San Fernando Valley - Ventura County
#
#       SUBMARKET_CODE    SUBMARKET_NAME  COUNTY_NAME  \
# ...

# %%
property_value['PROPERTY_ZIPCODE']=property_value['PROPERTY_ZIPCODE'].astype(int)
result=result.merge(property_value,on=['PROPERTY_ZIPCODE','year'])
result
# Out:
#        PROPERTY_ID  year  MARKETID                           MARKET_NAME  \
# 0       57_1345491  2016        57                          Jacksonville
# 1          57_1937  2016        57                          Jacksonville
# 2          57_1936  2016        57                          Jacksonville
# 3          57_1981  2016        57                          Jacksonville
# 4          57_1908  2016        57                          Jacksonville
# ...            ...   ...       ...                                   ...
# 388012      10_652  2022        10                         Inland Empire
# 388013     11_1062  2022        11          Los Angeles - Eastern County
# 388014     11_1766  2022        11          Los Angeles - Eastern County
# 388015   11_927079  2022        11          Los Angeles - Eastern County
# 388016     13_1020  2022        13  San Fernando Valley - Ventura County
#
#        SUBMARKET_CODE               SUBMARKET_NAME  COUNTY_NAME  \
# ...

# %%
frames = [CA_employed, FL_employed, South_employed, SE_employed, SW_employed, West_employed]

employed = pd.concat(frames)
employed['tract']=employed['tract'].astype(int)
employed['tract']=employed['tract'].abs()
result=result.merge(employed,on=['tract','year'],how='left')
result
# Out:
#        PROPERTY_ID  year  MARKETID                           MARKET_NAME  \
# 0       57_1345491  2016        57                          Jacksonville
# 1          57_1937  2016        57                          Jacksonville
# 2          57_1936  2016        57                          Jacksonville
# 3          57_1981  2016        57                          Jacksonville
# 4          57_1908  2016        57                          Jacksonville
# ...            ...   ...       ...                                   ...
# 456276      10_652  2022        10                         Inland Empire
# 456277     11_1062  2022        11          Los Angeles - Eastern County
# 456278     11_1766  2022        11          Los Angeles - Eastern County
# 456279   11_927079  2022        11          Los Angeles - Eastern County
# 456280     13_1020  2022        13  San Fernando Valley - Ventura County
#
#        SUBMARKET_CODE               SUBMARKET_NAME  COUNTY_NAME  \
# ...

# %%
result[result['16+_Employed'].isna() == True].loc[:, ['tract', '16+_Employed', '16+_Labor']]
# Out:
#              tract  16+_Employed  16+_Labor
# 0        865871182           NaN        NaN
# 1        865871181           NaN        NaN
# 2        865871182           NaN        NaN
# 3        795851578           NaN        NaN
# 5        795851684           NaN        NaN
# ...            ...           ...        ...
# 456257  1776034750           NaN        NaN
# 456258  1776034751           NaN        NaN
# 456263  1770075453           NaN        NaN
# 456264  1770075456           NaN        NaN
# 456280  1742832909           NaN        NaN
#
# [138831 rows x 3 columns]

# %%
employed[employed['tract'] == 12019030707]
# Out:
# Empty DataFrame
# Columns: [tract, year, 16+_Pop, 16+_Labor, 16+_Employed]
# Index: []

# %%
frames = [CA_income, FL_income, South_income, SE_income, SW_income, West_income]

income = pd.concat(frames)
income['tract']=income['tract'].astype(int)
income['tract']=income['tract'].abs()
result=result.merge(income,on=['tract','year'],how='left')
result
# Out:
#        PROPERTY_ID  year  MARKETID                           MARKET_NAME  \
# 0       57_1345491  2016        57                          Jacksonville
# 1          57_1937  2016        57                          Jacksonville
# 2          57_1936  2016        57                          Jacksonville
# 3          57_1981  2016        57                          Jacksonville
# 4          57_1908  2016        57                          Jacksonville
# ...            ...   ...       ...                                   ...
# 592804      10_652  2022        10                         Inland Empire
# 592805     11_1062  2022        11          Los Angeles - Eastern County
# 592806     11_1766  2022        11          Los Angeles - Eastern County
# 592807   11_927079  2022        11          Los Angeles - Eastern County
# 592808     13_1020  2022        13  San Fernando Valley - Ventura County
#
#        SUBMARKET_CODE               SUBMARKET_NAME  COUNTY_NAME  \
# ...

# %%
frames = [CA_pop, FL_pop, South_pop, SE_pop, SW_pop, West_pop]

population = pd.concat(frames)
population['tract']=population['tract'].astype(int)
population['tract']=population['tract'].abs()
result['tract']=result['tract'].astype(int)
result=result.merge(population,on=['tract','year'],how='left')
result
# Out:
#        PROPERTY_ID  year  MARKETID                           MARKET_NAME  \
# 0       57_1345491  2016        57                          Jacksonville
# 1          57_1937  2016        57                          Jacksonville
# 2          57_1936  2016        57                          Jacksonville
# 3          57_1981  2016        57                          Jacksonville
# 4          57_1908  2016        57                          Jacksonville
# ...            ...   ...       ...                                   ...
# 865860      10_652  2022        10                         Inland Empire
# 865861     11_1062  2022        11          Los Angeles - Eastern County
# 865862     11_1766  2022        11          Los Angeles - Eastern County
# 865863   11_927079  2022        11          Los Angeles - Eastern County
# 865864     13_1020  2022        13  San Fernando Valley - Ventura County
#
#        SUBMARKET_CODE               SUBMARKET_NAME  COUNTY_NAME  \
# ...

# %%
for x in population['tract'][0:20]:
    print(x,x in population['tract'])
# Out:
# 1706432804 False
# 1706432804 False
# 1706432804 False
# 1706432804 False
# 1706432804 False
# 1706432804 False
# 1706432804 False
# 1706432904 False
# 1706432904 False
# 1706432904 False
# 1706432904 False
# 1706432904 False
# 1706432904 False
# 1706432904 False
# 1706433004 False
# 1706433004 False
# 1706433004 False
# 1706433004 False
# 1706433004 False
# 1706433004 False

# %%
population['tract']
# Out:
# 0        1706432804
# 1        1706432804
# 2        1706432804
# 3        1706432804
# 4        1706432804
#             ...
# 42583     211376452
# 42584     211376452
# 42585     211376452
# 42586     211376452
# 42587     211376452
# Name: tract, Length: 289905, dtype: int32

# %%
house_16=house[house.year==2016]
house_17=house[house.year==2017]
house_18=house[house.year==2018]
house_19=house[house.year==2019]
house_20=house[house.year==2020]
house_21=house[house.year==2021]
house_22=house[house.year==2022]
house_16
# Out:
#           Date  Florida  Colorado  Texas  California  Ohio  Minnesota  \
# 336   1/1/2016     5268      1692   7607        3188  1002        991
# 337   2/1/2016     5560      1812   8949        4209  1460       1209
# 338   3/1/2016     6403      1778   9004        3917  1277       1147
# 339   4/1/2016     6144      1827   8588        4068  1214       1238
# 340   5/1/2016     6863      1774   8912        4066  1197       1177
# 341   6/1/2016     7008      1814   9053        4219  1319       1085
# 342   7/1/2016     6255      1721   8381        3283  1169       1017
# 343   8/1/2016     7403      1894   9408        4338  1302       1203
# 344   9/1/2016     6305      1846   9144        4465  1284       1178
# 345  10/1/2016     5589      1742   8872        4139  1164        928
# 346  11/1/2016     5245      1889   9190        4526  1465       1205
# 347  12/1/2016     5884      2018   9675        5111  1306       1306
#
# ...

# %%
df=house_16
s=pd.Series(df.mean(axis=0))
df=df.append(s,ignore_index=True)
df=df[df.Date.isna()]
house_supply=df

df=house_17
s=pd.Series(df.mean(axis=0))
df=df.append(s,ignore_index=True)
df=df[df.Date.isna()]
house_supply=house_supply.append(df)
house_supply

df=house_18
s=pd.Series(df.mean(axis=0))
df=df.append(s,ignore_index=True)
df=df[df.Date.isna()]
house_supply=house_supply.append(df)

df=house_19
s=pd.Series(df.mean(axis=0))
df=df.append(s,ignore_index=True)
df=df[df.Date.isna()]
house_supply=house_supply.append(df)

df=house_20
s=pd.Series(df.mean(axis=0))
df=df.append(s,ignore_index=True)
df=df[df.Date.isna()]
house_supply=house_supply.append(df)

df=house_21
s=pd.Series(df.mean(axis=0))
df=df.append(s,ignore_index=True)
df=df[df.Date.isna()]
house_supply=house_supply.append(df)

df=house_22
s=pd.Series(df.mean(axis=0))
df=df.append(s,ignore_index=True)
df=df[df.Date.isna()]
house_supply=house_supply.append(df)
house_supply=house_supply.drop(columns=['Date'])
house_supply=house_supply.astype(int)
house_supply
# Out:
#     Florida  Colorado  Texas  California  Ohio  Minnesota  Montana  \
# 12     6160      1817   8898        4127  1263       1140      204
# 12     6943      2079   9783        4831  1366       1227      207
# 12     7908      2432  10238        5203  1332       1172      222
# 12     8262      2312  10553        4942  1285       1196      182
# 12     9595      2757  12995        5146  1534       1326      223
# 12    12050      2853  14425        5503  1700       1532      249
# 4     12635      2593  15152        5819  1626       1411      352
#
#     Massachusetts  Arizonia  Rhode Island  ...  Delaware  Hawaii  Iowa  \
# 12            619      2024            74  ...       403     183   691
# 12            655      2287            89  ...       438     210   718
# 12            557      2619            75  ...       459     220   651
# 12            484      2746            76  ...       465     214   706
# 12            555      3504            80  ...       594     185   809
# ...

# %%
house_supply.rename(columns={"Arizonia": "Arizona"}, inplace = True)
house_supply
# Out:
#     Florida  Colorado  Texas  California  Ohio  Minnesota  Montana  \
# 12     6160      1817   8898        4127  1263       1140      204
# 12     6943      2079   9783        4831  1366       1227      207
# 12     7908      2432  10238        5203  1332       1172      222
# 12     8262      2312  10553        4942  1285       1196      182
# 12     9595      2757  12995        5146  1534       1326      223
# 12    12050      2853  14425        5503  1700       1532      249
# 4     12635      2593  15152        5819  1626       1411      352
#
#     Massachusetts  Arizona  Rhode Island  ...  Delaware  Hawaii  Iowa  Kansas  \
# 12            619     2024            74  ...       403     183   691     422
# 12            655     2287            89  ...       438     210   718     490
# 12            557     2619            75  ...       459     220   651     464
# 12            484     2746            76  ...       465     214   706     399
# ...

# %%
house_supply=house_supply.melt(id_vars=['year'],value_vars=['Florida', 'Colorado', 'Texas', 'California', 'Ohio', 'Minnesota',
       'Montana', 'Massachusetts', 'Arizona', 'Rhode Island', 'Maine',
       'Virginia', 'New York', 'Alabama', 'West Virginia', 'Georgia',
       'Oklahoma', 'Vermont', 'Nevada', 'Mississippi', 'Michigan', 'Indiana',
       'North Carolina', 'New Mexico', 'Pennsylvania', 'Utah', 'Arkansas',
       'Kentucky', 'Maryland', 'Louisiana', 'Wyoming', 'Tennessee',
       'Connecticut', 'Idaho', 'Illinois', 'South Carolina', 'South Dakota',
       'New Jersey', 'Washington', 'New Hampshire', 'Alaska', 'Delaware',
       'Hawaii', 'Iowa', 'Kansas', 'Missouri', 'Nebraska', 'Oregon',
       'North Dakota', 'Wisconsin'])
house_supply=house_supply.rename(columns={'variable':'PROPERTY_STATE','value':'house_supply'})
house_supply['PROPERTY_STATE'] = house_supply['PROPERTY_STATE'].map(states) 
house_supply
# Out:
#      year PROPERTY_STATE  house_supply
# 0    2016             FL          6160
# 1    2017             FL          6943
# 2    2018             FL          7908
# 3    2019             FL          8262
# 4    2020             FL          9595
# ..    ...            ...           ...
# 345  2018             WI           965
# 346  2019             WI           907
# 347  2020             WI          1050
# 348  2021             WI          1125
# 349  2022             WI          1112
#
# [350 rows x 3 columns]

# %%
house_supply['PROPERTY_STATE'].isna().sum()
# Out:
# 0

# %%
result=result.merge(house_supply,on=['PROPERTY_STATE','year'],how='left')
result.head()
# Out:
#   PROPERTY_ID  year  MARKETID   MARKET_NAME SUBMARKET_CODE    SUBMARKET_NAME  \
# 0  57_1345491  2016        57  Jacksonville           29.0    Fleming Island
# 1     57_1937  2016        57  Jacksonville           29.0    Fleming Island
# 2     57_1936  2016        57  Jacksonville           29.0    Fleming Island
# 3     57_1981  2016        57  Jacksonville           24.0  Fernandina Beach
# 4     57_1908  2016        57  Jacksonville           24.0  Fernandina Beach
#
#   COUNTY_NAME                 PROPERTY_NAME         PROPERTY_PRIORNAMES  \
# 0        Clay   Station Fleming Island, The                Station, The
# 1        Clay   Cobblestone at Eagle Harbor  Vineyards at Eagle Harbour
# 2        Clay  Lighthouse at Fleming Island            Lighthouse Court
# 3      Nassau                  Amelia Lakes                         NaN
# 4      Nassau         Marsh Cove & Somerset                    Somerset
#
# ...

# %%
result['house_supply'].isna().sum()
# Out:
# 0

# %%
frames = [SoCal_occupancy, FL_occupancy, South_occupancy, SE_occupancy, SW_occupancy, West_occupancy]

occupancy = pd.concat(frames)
result=result.merge(occupancy,on=['PROPERTY_ID','year'],how='left')
result
# Out:
#        PROPERTY_ID  year  MARKETID                           MARKET_NAME  \
# 0       57_1345491  2016        57                          Jacksonville
# 1          57_1937  2016        57                          Jacksonville
# 2          57_1936  2016        57                          Jacksonville
# 3          57_1981  2016        57                          Jacksonville
# 4          57_1908  2016        57                          Jacksonville
# ...            ...   ...       ...                                   ...
# 865860      10_652  2022        10                         Inland Empire
# 865861     11_1062  2022        11          Los Angeles - Eastern County
# 865862     11_1766  2022        11          Los Angeles - Eastern County
# 865863   11_927079  2022        11          Los Angeles - Eastern County
# 865864     13_1020  2022        13  San Fernando Valley - Ventura County
#
#        SUBMARKET_CODE               SUBMARKET_NAME  COUNTY_NAME  \
# ...

# %%
frames = [SoCal_rent, FL_rent, South_rent, SE_rent, SW_rent, West_rent]

rent = pd.concat(frames)
result=result.merge(rent,on=['PROPERTY_ID','year'],how='left')
result
# Out:
#        PROPERTY_ID  year  MARKETID                           MARKET_NAME  \
# 0       57_1345491  2016        57                          Jacksonville
# 1          57_1937  2016        57                          Jacksonville
# 2          57_1936  2016        57                          Jacksonville
# 3          57_1981  2016        57                          Jacksonville
# 4          57_1908  2016        57                          Jacksonville
# ...            ...   ...       ...                                   ...
# 865860      10_652  2022        10                         Inland Empire
# 865861     11_1062  2022        11          Los Angeles - Eastern County
# 865862     11_1766  2022        11          Los Angeles - Eastern County
# 865863   11_927079  2022        11          Los Angeles - Eastern County
# 865864     13_1020  2022        13  San Fernando Valley - Ventura County
#
#        SUBMARKET_CODE               SUBMARKET_NAME  COUNTY_NAME  \
# ...

# %%
frames = [SoCal_rent_per, FL_rent_per, South_rent_per, SE_rent_per, SW_rent_per, West_rent_per]

rent_per = pd.concat(frames)
result=result.merge(rent_per,on=['PROPERTY_ID','year'],how='left')
result
# Out:
#        PROPERTY_ID  year  MARKETID                           MARKET_NAME  \
# 0       57_1345491  2016        57                          Jacksonville
# 1          57_1937  2016        57                          Jacksonville
# 2          57_1936  2016        57                          Jacksonville
# 3          57_1981  2016        57                          Jacksonville
# 4          57_1908  2016        57                          Jacksonville
# ...            ...   ...       ...                                   ...
# 865860      10_652  2022        10                         Inland Empire
# 865861     11_1062  2022        11          Los Angeles - Eastern County
# 865862     11_1766  2022        11          Los Angeles - Eastern County
# 865863   11_927079  2022        11          Los Angeles - Eastern County
# 865864     13_1020  2022        13  San Fernando Valley - Ventura County
#
#        SUBMARKET_CODE               SUBMARKET_NAME  COUNTY_NAME  \
# ...

# %%
result.drop(columns = 'Unnamed: 0', inplace = True)

# %%
#Remove duplicates
result=result.drop_duplicates(subset=['PROPERTY_ID','year'], keep='first')
result
# Out:
#        PROPERTY_ID  year  MARKETID                           MARKET_NAME  \
# 0       57_1345491  2016        57                          Jacksonville
# 1          57_1937  2016        57                          Jacksonville
# 2          57_1936  2016        57                          Jacksonville
# 3          57_1981  2016        57                          Jacksonville
# 4          57_1908  2016        57                          Jacksonville
# ...            ...   ...       ...                                   ...
# 865860      10_652  2022        10                         Inland Empire
# 865861     11_1062  2022        11          Los Angeles - Eastern County
# 865862     11_1766  2022        11          Los Angeles - Eastern County
# 865863   11_927079  2022        11          Los Angeles - Eastern County
# 865864     13_1020  2022        13  San Fernando Valley - Ventura County
#
#        SUBMARKET_CODE               SUBMARKET_NAME  COUNTY_NAME  \
# ...

# %%
crime['series'] = crime['series'].map(states) 
crime=crime.rename(columns={"series": "PROPERTY_STATE"})
crime=pd.melt(crime,id_vars=['PROPERTY_STATE'],value_vars=['2016','2017','2018','2019','2020'])
crime=crime.rename(columns={"variable": "year",'value':'crime_rate'})
crime
# Out:
#     PROPERTY_STATE  year  crime_rate
# 0               AL  2016       532.4
# 1               AK  2016       804.6
# 2               AZ  2016       471.0
# 3               AR  2016       554.3
# 4               CA  2016       444.8
# ..             ...   ...         ...
# 250             VA  2020       208.7
# 251             WA  2020       293.7
# 252             WV  2020       355.9
# 253             WI  2020       323.4
# 254             WY  2020       234.2
#
# [255 rows x 3 columns]

# %%
crime.isna().sum()
# Out:
# PROPERTY_STATE    0
# year              0
# crime_rate        0
# dtype: int64

# %%
crime['year']=crime['year'].astype(int)
crime['PROPERTY_STATE']=crime['PROPERTY_STATE'].astype(str)
result['year']=result['year'].astype(int)
result['PROPERTY_STATE']=result['PROPERTY_STATE'].astype(str)

result=result.merge(crime,on=['PROPERTY_STATE','year'],how='left')
result
# Out:
# <ipython-input-152-bba0adb1d99f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['year']=result['year'].astype(int)
# <ipython-input-152-bba0adb1d99f>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result['PROPERTY_STATE']=result['PROPERTY_STATE'].astype(str)
#        PROPERTY_ID  year  MARKETID                           MARKET_NAME  \
# 0       57_1345491  2016        57                          Jacksonville
# ...

# %%
result['crime_rate'].isna().sum()
# Out:
# 72968

# %%
bond['year']=bond['Annual Returns on Investments in Year']
bond=bond.drop(columns=['Annual Returns on Investments in Year','Unnamed: 0'])
bond=bond.rename(columns={bond.columns[3]: 'corp_bond'})
bond=bond.rename(columns={bond.columns[8]: 'baa_corp_bond'})
bond
# Out:
#     Annual Returns on Investments in S&P 500 (includes dividends)  \
# 0                                             -0.1185
# 1                                             -0.2197
# 2                                              0.2836
# 3                                              0.1074
# 4                                              0.0483
# 5                                              0.1561
# 6                                              0.0548
# 7                                             -0.3655
# 8                                              0.2594
# 9                                              0.1482
# 10                                             0.0210
# 11                                             0.1589
# 12                                             0.3215
# 13                                             0.1352
# 14                                             0.0138
# 15                                             0.1177
# ...

# %%
bond['S&P 500 (includes dividends)3']=bond['S&P 500 (includes dividends)3'].str.replace("$","")
bond['S&P 500 (includes dividends)3']=bond['S&P 500 (includes dividends)3'].str.replace(",","")
bond['S&P 500 (includes dividends)3']=bond['S&P 500 (includes dividends)3'].str.replace(" ","")
bond['S&P 500 (includes dividends)3']=bond['S&P 500 (includes dividends)3'].astype(float)
bond['3-month T.Bill4']=bond['3-month T.Bill4'].str.replace("$","")
bond['3-month T.Bill4']=bond['3-month T.Bill4'].str.replace(",","")
bond['3-month T.Bill4']=bond['3-month T.Bill4'].str.replace(" ","")
bond['3-month T.Bill4']=bond['3-month T.Bill4'].astype(float)
bond['US T. Bond5']=bond['US T. Bond5'].str.replace("$","")
bond['US T. Bond5']=bond['US T. Bond5'].str.replace(",","")
bond['US T. Bond5']=bond['US T. Bond5'].str.replace(" ","")
bond['US T. Bond5']=bond['US T. Bond5'].astype(float)
bond['baa_corp_bond']=bond['baa_corp_bond'].str.replace("$","")
bond['baa_corp_bond']=bond['baa_corp_bond'].str.replace(",","")
bond['baa_corp_bond']=bond['baa_corp_bond'].str.replace(" ","")
bond['baa_corp_bond']=bond['baa_corp_bond'].astype(float)
bond['Real Estate2']=bond['Real Estate2'].str.replace("$","")
bond['Real Estate2']=bond['Real Estate2'].str.replace(",","")
bond['Real Estate2']=bond['Real Estate2'].str.replace(" ","")
bond['Real Estate2']=bond['Real Estate2'].astype(float)
# Out:
# <ipython-input-155-cfe13ef610cb>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   bond['S&P 500 (includes dividends)3']=bond['S&P 500 (includes dividends)3'].str.replace("$","")
# <ipython-input-155-cfe13ef610cb>:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   bond['3-month T.Bill4']=bond['3-month T.Bill4'].str.replace("$","")
# <ipython-input-155-cfe13ef610cb>:9: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   bond['US T. Bond5']=bond['US T. Bond5'].str.replace("$","")
# ...

# %%
result=result.merge(bond,on='year',how='left')
result
# Out:
#        PROPERTY_ID  year  MARKETID                           MARKET_NAME  \
# 0       57_1345491  2016        57                          Jacksonville
# 1          57_1937  2016        57                          Jacksonville
# 2          57_1936  2016        57                          Jacksonville
# 3          57_1981  2016        57                          Jacksonville
# 4          57_1908  2016        57                          Jacksonville
# ...            ...   ...       ...                                   ...
# 255383      10_652  2022        10                         Inland Empire
# 255384     11_1062  2022        11          Los Angeles - Eastern County
# 255385     11_1766  2022        11          Los Angeles - Eastern County
# 255386   11_927079  2022        11          Los Angeles - Eastern County
# 255387     13_1020  2022        13  San Fernando Valley - Ventura County
#
#        SUBMARKET_CODE               SUBMARKET_NAME  COUNTY_NAME  \
# ...

# %%
result['rent']=result['Avg_RentActual']
result['rent_per']=result['Avg_RentPerSqFtActual']
result=result.drop(columns=['MARKETID', 'MARKET_NAME', 'SUBMARKET_CODE',
       'SUBMARKET_NAME', 'COUNTY_NAME', 'PROPERTY_NAME', 'PROPERTY_PRIORNAMES',
       'PROPERTY_ADDRESS', 'PROPERTY_CITY',
       'PROPERTY_ZIPCODE', 'lat', 'lon', 'PROPERTY_PHONE','PROPERTY_ACRES', 'PROPERTY_IMPRATING',
       'PROPERTY_LOCRATING', 'PROPERTY_STATUS', 'PROPERTY_DATE_PLANNED',
       'PROPERTY_DATE_UNDERCONSTRUCTION', 'PROPERTY_DATE_RENTUP',
       'PROPERTY_DATECOMPLETED', 'PROPERTY_MIXEDUSE',
       'PROPERTY_MIXEDUSE_NOTES', 'PROPERTY_STUDENTHOUSING',
       'PROPERTY_AFFORDABLEHOUSING', 'PROPERTY_MILITARYHOUSING',
       'PROPERTY_AGERESTRICTED', 'PROPERTY_FRACTUREDCONDO',
       'PROPERTY_ADAPTIVEREUSE', 'PROPERTY_SINGLEFAMILYRENTAL',
       'PROPERTY_CURRENT_OCCUPANCY','PROPERTY_MATRIX_URL', 'block','Avg_RentActual','Avg_RentPerSqFtActual'])
result
# Out:
#        PROPERTY_ID  year PROPERTY_STATE  PROPERTY_UNITS  PROPERTY_SQFT  \
# 0       57_1345491  2016             FL             180            0.0
# 1          57_1937  2016             FL             260       267355.0
# 2          57_1936  2016             FL             501       556393.0
# 3          57_1981  2016             FL              56        62733.0
# 4          57_1908  2016             FL             167       172153.0
# ...            ...   ...            ...             ...            ...
# 255383      10_652  2022             CA             628       482884.0
# 255384     11_1062  2022             CA            1175       889651.0
# 255385     11_1766  2022             CA            1030            0.0
# 255386   11_927079  2022             CA             850            0.0
# 255387     13_1020  2022             CA             699       572210.0
#
#         PROPERTY_CURRENT_RENT       tract region county state_code  ...  \
# ...

# %%
result.tract
# Out:
# 0          865871182
# 1          865871181
# 2          865871182
# 3          795851578
# 4          795851685
#              ...
# 255383    1770074513
# 255384    1742237824
# 255385    1742238754
# 255386    1742565008
# 255387    1742832909
# Name: tract, Length: 255388, dtype: int32

# %% [markdown]
# **Convert rent variable to growth**

# %%
result['rent_scaled']=result['PROPERTY_UNITS']*result['rent']
result['rent_scaled_per']=result['PROPERTY_UNITS']*result['rent_per']
result
# Out:
#        PROPERTY_ID  year PROPERTY_STATE  PROPERTY_UNITS  PROPERTY_SQFT  \
# 0       57_1345491  2016             FL             180            0.0
# 1          57_1937  2016             FL             260       267355.0
# 2          57_1936  2016             FL             501       556393.0
# 3          57_1981  2016             FL              56        62733.0
# 4          57_1908  2016             FL             167       172153.0
# ...            ...   ...            ...             ...            ...
# 255383      10_652  2022             CA             628       482884.0
# 255384     11_1062  2022             CA            1175       889651.0
# 255385     11_1766  2022             CA            1030            0.0
# 255386   11_927079  2022             CA             850            0.0
# 255387     13_1020  2022             CA             699       572210.0
#
#         PROPERTY_CURRENT_RENT       tract region county state_code  ...  \
# ...

# %%
result_16=result[result['year']==2016]
result_17=result[result['year']==2017]
result_18=result[result['year']==2018]
result_19=result[result['year']==2019]
result_20=result[result['year']==2020]
result_21=result[result['year']==2021]
result_22=result[result['year']==2022]

# %%
group_15=pd.read_csv('AllRegions_2015_Rent-RentperSfFt-OccupationRate.csv')
rent_15=group_15[group_15.SERIES=='Rent Actual'].drop(columns=['SERIES'])
rent_15
# Out:
#        PROPERTY_ID    Avg_value
# 1            101_1   666.083333
# 4         101_1002   794.250000
# 7         101_1006   926.166667
# 10        101_1007  1049.750000
# 13        101_1008  1070.083333
# ...            ...          ...
# 103276       95_94   899.545455
# 103279       95_95   658.833333
# 103282       95_96  1293.272727
# 103285       95_98   753.833333
# 103288       95_99  1105.083333
#
# [34430 rows x 2 columns]

# %%
rent_per_15=group_15[group_15.SERIES=='Rent Per SqFt Actual'].drop(columns=['SERIES'])
rent_per_15
# Out:
#        PROPERTY_ID  Avg_value
# 2            101_1   0.800833
# 5         101_1002   1.020833
# 8         101_1006   1.280000
# 11        101_1007   0.997500
# 14        101_1008   0.961667
# ...            ...        ...
# 103277       95_94   0.810000
# 103280       95_95   1.253333
# 103283       95_96   1.822727
# 103286       95_98   0.710833
# 103289       95_99   1.074167
#
# [34430 rows x 2 columns]

# %%
result_16=result_16.merge(rent_15,on='PROPERTY_ID',how='left')
result_16['growth']=(result_16['rent']/result_16['Avg_value']*100)-100
result_16=result_16.drop(columns=['Avg_value'])

# %%
result_16=result_16.merge(rent_per_15,on='PROPERTY_ID',how='left')
result_16['growth_per']=(result_16['rent_per']/result_16['Avg_value']*100)-100
result_16=result_16.drop(columns=['Avg_value'])
result_16
# Out:
#       PROPERTY_ID  year PROPERTY_STATE  PROPERTY_UNITS  PROPERTY_SQFT  \
# 0      57_1345491  2016             FL             180            0.0
# 1         57_1937  2016             FL             260       267355.0
# 2         57_1936  2016             FL             501       556393.0
# 3         57_1981  2016             FL              56        62733.0
# 4         57_1908  2016             FL             167       172153.0
# ...           ...   ...            ...             ...            ...
# 36479      10_652  2016             CA             628       482884.0
# 36480     11_1062  2016             CA            1175       889651.0
# 36481     11_1766  2016             CA            1030            0.0
# 36482   11_927079  2016             CA             850            0.0
# 36483     13_1020  2016             CA             699       572210.0
#
#        PROPERTY_CURRENT_RENT       tract region county state_code  ...  \
# ...

# %%
#add growth code here
s=[]
zipp=zip(result_16['rent_scaled'],result_17['rent_scaled'])
for x,y in zipp:
    per=(y/x*100)-100
    s.append(per)
result_17['growth']=s
s=[]
zipp=zip(result_17['rent_scaled'],result_18['rent_scaled'])
for x,y in zipp:
    per=(y/x*100)-100
    s.append(per)
result_18['growth']=s
s=[]
zipp=zip(result_18['rent_scaled'],result_19['rent_scaled'])
for x,y in zipp:
    per=(y/x*100)-100
    s.append(per)
result_19['growth']=s
s=[]
zipp=zip(result_19['rent_scaled'],result_20['rent_scaled'])
for x,y in zipp:
    per=(y/x*100)-100
    s.append(per)
result_20['growth']=s
s=[]
zipp=zip(result_20['rent_scaled'],result_21['rent_scaled'])
for x,y in zipp:
    per=(y/x*100)-100
    s.append(per)
result_21['growth']=s
s=[]
zipp=zip(result_21['rent_scaled'],result_22['rent_scaled'])
for x,y in zipp:
    per=(y/x*100)-100
    s.append(per)
result_22['growth']=s
# Out:
# <ipython-input-165-c10da9b551ae>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_17['growth']=s
# <ipython-input-165-c10da9b551ae>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_18['growth']=s
# <ipython-input-165-c10da9b551ae>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#add growth code here
s=[]
zipp=zip(result_16['rent_scaled_per'],result_17['rent_scaled_per'])
for x,y in zipp:
    per=(y/x*100)-100
    s.append(per)
result_17['growth_per']=s
s=[]
zipp=zip(result_17['rent_scaled_per'],result_18['rent_scaled_per'])
for x,y in zipp:
    per=(y/x*100)-100
    s.append(per)
result_18['growth_per']=s
s=[]
zipp=zip(result_18['rent_scaled_per'],result_19['rent_scaled_per'])
for x,y in zipp:
    per=(y/x*100)-100
    s.append(per)
result_19['growth_per']=s
s=[]
zipp=zip(result_19['rent_scaled_per'],result_20['rent_scaled_per'])
for x,y in zipp:
    per=(y/x*100)-100
    s.append(per)
result_20['growth_per']=s
s=[]
zipp=zip(result_20['rent_scaled_per'],result_21['rent_scaled_per'])
for x,y in zipp:
    per=(y/x*100)-100
    s.append(per)
result_21['growth_per']=s
s=[]
zipp=zip(result_21['rent_scaled_per'],result_22['rent_scaled_per'])
for x,y in zipp:
    per=(y/x*100)-100
    s.append(per)
result_22['growth_per']=s
# Out:
# <ipython-input-166-3ee662ec3324>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_17['growth_per']=s
# <ipython-input-166-3ee662ec3324>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_18['growth_per']=s
# <ipython-input-166-3ee662ec3324>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
result_16[result_16['tract'] == 56041975301]
# Out:
# Empty DataFrame
# ...

# %%
frames=[result_16,result_17,result_18,result_19,result_20,result_21,result_22]
result=pd.concat(frames)
result
# Out:
#        PROPERTY_ID  year PROPERTY_STATE  PROPERTY_UNITS  PROPERTY_SQFT  \
# 0       57_1345491  2016             FL             180            0.0
# 1          57_1937  2016             FL             260       267355.0
# 2          57_1936  2016             FL             501       556393.0
# 3          57_1981  2016             FL              56        62733.0
# 4          57_1908  2016             FL             167       172153.0
# ...            ...   ...            ...             ...            ...
# 255383      10_652  2022             CA             628       482884.0
# 255384     11_1062  2022             CA            1175       889651.0
# 255385     11_1766  2022             CA            1030            0.0
# 255386   11_927079  2022             CA             850            0.0
# 255387     13_1020  2022             CA             699       572210.0
#
#         PROPERTY_CURRENT_RENT       tract region county state_code  ...  \
# ...

# %%
# result = result.sort_values(by=['PROPERTY_ID', 'year']).reset_index(drop=True)
# result['rent'] = result['rent'].bfill(axis ='rows')
# result['rent_per'] = result['rent_per'].bfill(axis ='rows')

# %%
#result[result['tract'].isna()]

# %%
result=result[result['rent'].notna()]
result=result[result['rent_per'].notna()]
result
# Out:
#        PROPERTY_ID  year PROPERTY_STATE  PROPERTY_UNITS  PROPERTY_SQFT  \
# 1          57_1937  2016             FL             260       267355.0
# 2          57_1936  2016             FL             501       556393.0
# 3          57_1981  2016             FL              56        62733.0
# 4          57_1908  2016             FL             167       172153.0
# 7          57_1959  2016             FL             392       318700.0
# ...            ...   ...            ...             ...            ...
# 255381       3_662  2022             CA             549       376443.0
# 255382       7_169  2022             CA             421       399365.0
# 255383      10_652  2022             CA             628       482884.0
# 255384     11_1062  2022             CA            1175       889651.0
# 255387     13_1020  2022             CA             699       572210.0
#
#         PROPERTY_CURRENT_RENT       tract region county state_code  ...  \
# ...

# %%
result['rent'].isna().sum()
# Out:
# 0

# %%
result[result['male_population'].isna()].tract.value_counts()
# Out:
# 789884866     92
# 576183725     91
# 1742735604    91
# 558931886     91
# 956889845     87
#               ..
# 1208361961     1
# 787858680      1
# 840390051      1
# 775881080      1
# 956691246      1
# Name: tract, Length: 4254, dtype: int64

# %%
result.tract.value_counts()
# Out:
# 1742734606    129
# 1742222906    121
# 1742244507    101
# 956815044      99
# 1742241414     98
#              ...
# 1790471446      1
# 2015768372      1
# 775881080       1
# 281874575       1
# 840390051       1
# Name: tract, Length: 12503, dtype: int64

# %%
result.columns
# Out:
# Index(['PROPERTY_ID', 'year', 'PROPERTY_STATE', 'PROPERTY_UNITS',
#        'PROPERTY_SQFT', 'PROPERTY_CURRENT_RENT', 'tract', 'region', 'county',
#        'state_code', 'Tract Area', 'Zipcode', 'Area', 'State Tax Rate',
#        'Avg. Local Tax Rate', 'Combined Rate', 'Max Local Tax Rate',
#        'corporate_tax', 'income_tax', 'starbucks', 'hospitals', 'colleges',
#        'banks', 'public_school', 'private_school', 'grocery_vists',
#        'avg_house_income', 'median_debt', 'property_value', '16+_Pop',
#        '16+_Labor', '16+_Employed', 'median_income', 'population', 'white_pop',
#        'Black_pop', 'Native_pop', 'Asian_pop', 'Pacific_pop',
#        'male_population', 'female_population', '0-19_pop', '20-29_pop',
#        '30-39_pop', '40-49_pop', '50-59_pop', '60-69_pop', '70+_pop',
#        'house_supply', 'Occupancy_rate', 'crime_rate',
#        'Annual Returns on Investments in S&P 500 (includes dividends)',
#        'Annual Returns on Investments in 3-month T.Bill',
# ...

# %% [markdown]
# # Group By Tract

# %%
group=result.groupby(['tract','year']).agg(
    growth=pd.NamedAgg(column='growth', aggfunc='mean'), 
    growth_per_sqft=pd.NamedAgg(column='growth_per', aggfunc='mean'), 
    mean_rent=pd.NamedAgg(column='rent', aggfunc='mean'), 
    mean_rent_per=pd.NamedAgg(column='rent_per', aggfunc='mean'),
    total_units=pd.NamedAgg(column='PROPERTY_UNITS', aggfunc= 'mean'),
    region=pd.NamedAgg(column='region', aggfunc= 'max'),
    state_code=pd.NamedAgg(column='state_code', aggfunc= 'max'),
    county=pd.NamedAgg(column='county', aggfunc= 'max'),
    property_sqft=pd.NamedAgg(column='PROPERTY_SQFT',aggfunc= 'mean'),
    current_rent=pd.NamedAgg(column='PROPERTY_CURRENT_RENT', aggfunc= 'mean'),
    state=pd.NamedAgg(column='PROPERTY_STATE', aggfunc= 'max'),
    #tract_area=pd.NamedAgg(column='Tract Area', aggfunc= 'mean'),
    zip_area=pd.NamedAgg(column='Area', aggfunc= 'mean'),
    property_value=pd.NamedAgg(column='property_value',aggfunc= 'mean'),
    income_tax_rate=pd.NamedAgg(column='income_tax',aggfunc= 'mean'),
    corporate_tax_rate=pd.NamedAgg(column='corporate_tax',aggfunc= 'mean'),
    state_sales_tax_rate=pd.NamedAgg(column='State Tax Rate',aggfunc= 'mean'),
    avg_local_sales_tax_rate=pd.NamedAgg(column='Avg. Local Tax Rate', aggfunc= 'mean'),
    combined_rate=pd.NamedAgg(column='Combined Rate', aggfunc= 'mean'),
    max_local_sales_tax=pd.NamedAgg(column='Max Local Tax Rate',aggfunc= 'mean'),
    grocery_vists=pd.NamedAgg(column='grocery_vists', aggfunc= 'mean'),
    starbucks_vists=pd.NamedAgg(column='starbucks', aggfunc= 'mean'),
    banks=pd.NamedAgg(column='banks', aggfunc= 'mean'),
    colleges=pd.NamedAgg(column='colleges', aggfunc= 'mean'),
    public_schools=pd.NamedAgg(column='public_school', aggfunc= 'mean'),
    private_schools=pd.NamedAgg(column='private_school', aggfunc= 'mean'),
    hospitals=pd.NamedAgg(column='hospitals', aggfunc= 'mean'),
   # food_stores=pd.NamedAgg(column='food_stores', aggfunc= 'mean'),
    over16_pop=pd.NamedAgg(column='16+_Pop', aggfunc= 'mean'),
    over16_labor=pd.NamedAgg(column='16+_Labor', aggfunc= 'mean'),
    over16_employed=pd.NamedAgg(column='16+_Employed',aggfunc= 'mean'),
    median_income=pd.NamedAgg(column='median_income', aggfunc='mean' ),
    avg_household_income=pd.NamedAgg(column='avg_house_income', aggfunc='mean'),
    median_debt=pd.NamedAgg(column='median_debt', aggfunc='mean'),
    population=pd.NamedAgg(column='population', aggfunc= 'mean'),
    white_pop=pd.NamedAgg(column='white_pop',aggfunc= 'mean'),
    black_pop=pd.NamedAgg(column='Black_pop', aggfunc= 'mean'),
    native_pop=pd.NamedAgg(column='Native_pop',aggfunc= 'mean'),
    asian_pop=pd.NamedAgg(column='Asian_pop', aggfunc= 'mean'),
    pacific_pop=pd.NamedAgg(column='Pacific_pop',aggfunc= 'mean'),
    male_population=pd.NamedAgg(column='male_population',aggfunc= 'mean'),
    female_population=pd.NamedAgg(column='female_population',aggfunc= 'mean'),
    pop_0_19=pd.NamedAgg(column='0-19_pop', aggfunc= 'mean'),
    pop_20_29=pd.NamedAgg(column='20-29_pop',aggfunc= 'mean'),
    pop_30_39=pd.NamedAgg(column='30-39_pop', aggfunc= 'mean'),
    pop_40_49=pd.NamedAgg(column='40-49_pop',aggfunc= 'mean'),
    pop_50_59=pd.NamedAgg(column='50-59_pop',aggfunc= 'mean'),
    pop_60_69=pd.NamedAgg(column='60-69_pop', aggfunc= 'mean'),
    pop_70_over=pd.NamedAgg(column='70+_pop', aggfunc= 'mean'),
    occupancy_rate=pd.NamedAgg(column='Occupancy_rate',aggfunc= 'mean'),
    house_supply=pd.NamedAgg(column='house_supply',aggfunc= 'mean'),
    crime_rate=pd.NamedAgg(column='crime_rate',aggfunc= 'mean'),
    ROI_SP500=pd.NamedAgg(column='Annual Returns on Investments in S&P 500 (includes dividends)',aggfunc= 'mean'),
    ROI_Tbill=pd.NamedAgg(column='Annual Returns on Investments in 3-month T.Bill',aggfunc= 'mean'),
    ROI_Tbond=pd.NamedAgg(column='Annual Returns on Investments in US T. Bond',aggfunc= 'mean'),
    corp_bond=pd.NamedAgg(column='corp_bond', aggfunc= 'mean'),
    real_estate=pd.NamedAgg(column='Real Estate',aggfunc= 'mean'),
    sp500=pd.NamedAgg(column='S&P 500 (includes dividends)3', aggfunc= 'mean'),
    Tbill=pd.NamedAgg(column='3-month T.Bill4', aggfunc= 'mean'),
    Tbond5=pd.NamedAgg(column='US T. Bond5',aggfunc= 'mean'),
    baa_corp_bond=pd.NamedAgg(column='baa_corp_bond',aggfunc= 'mean'),
    real_estate2=pd.NamedAgg(column='Real Estate2', aggfunc= 'mean'),
    stocks_bills=pd.NamedAgg(column='Stocks - Bills',aggfunc= 'mean'),
    stocks_bonds=pd.NamedAgg(column='Stocks - Bonds',aggfunc= 'mean'),
    stocks_corp_bonds=pd.NamedAgg(column='Stocks - Baa Corp Bond', aggfunc= 'mean'),
    hist_risk=pd.NamedAgg(column='Historical risk premium',aggfunc= 'mean'),
    inflation=pd.NamedAgg(column='Inflation Rate',aggfunc= 'mean'),
    SP500=pd.NamedAgg(column='S&P 500 (includes dividends)2',aggfunc= 'mean'),
    Tbill_3month=pd.NamedAgg(column='3-month T. Bill (Real)',aggfunc= 'mean'),
    Tbond_10year=pd.NamedAgg(column='!0-year T.Bonds',aggfunc= 'mean'), 
    baa_corp_bonds=pd.NamedAgg(column='Baa Corp Bonds',aggfunc= 'mean'),
    real_estate3=pd.NamedAgg(column='Real Estate3',aggfunc= 'mean'),   
#     grocery_vists=pd.NamedAgg(column='grocery_vists', aggfunc= 'mean'),
#     starbucks_vists=pd.NamedAgg(column='starbucks', aggfunc= 'mean'),
#     banks=pd.NamedAgg(column='banks', aggfunc= 'mean'),
#     colleges=pd.NamedAgg(column='colleges', aggfunc= 'mean'),
#     public_schools=pd.NamedAgg(column='public_school', aggfunc= 'mean'),
#     private_schools=pd.NamedAgg(column='private_school', aggfunc= 'mean'),
#     hospitals=pd.NamedAgg(column='hospitals', aggfunc= 'mean'),
)
group
# Out:
#                     growth  growth_per_sqft    mean_rent  mean_rent_per  \
# tract      year
# 1769769    2020        NaN              NaN   821.166667       1.136667
#            2021  11.441839        11.479203   915.375000       1.266667
#            2022  10.637266        10.545490  1011.300000       1.400000
# 1769770    2020        NaN              NaN   915.000000       0.950000
#            2021  12.550091        12.894737  1029.833333       1.072500
# ...                    ...              ...          ...            ...
# 2141388749 2018   3.604958         3.640439  1369.208333       1.079583
#            2019  -2.622504        -2.594340  1325.750000       1.047500
#            2020   6.680067         6.573501  1351.777778       1.129167
#            2021  13.866509        13.952979  1520.138889       1.280556
#            2022   8.248094         8.260151  1646.400000       1.387333
#
#                  total_units region state_code county  property_sqft  \
# ...

# %%
group['grocery_vists'].isna().sum()
# Out:
# 27427

# %%
group['grocery_vists'] = group['grocery_vists'].fillna(0)
group['grocery_vists'].isna().sum()
# Out:
# 0

# %%
group['starbucks_vists'] = group['starbucks_vists'].fillna(0)
group['banks'] = group['banks'].fillna(0)
group['colleges'] = group['colleges'].fillna(0)
group['public_schools'] = group['public_schools'].fillna(0)
group['private_schools'] = group['private_schools'].fillna(0)
group['hospitals'] = group['hospitals'].fillna(0)

# %%
#Percent of data that is null
mylist=100*group.isna().sum()/len(group)
for x,y in zip(mylist,list(group.columns)):
    print(y,'\t\t\t\t\t',x)
# Out:
# growth 					 1.7975650513248986
# growth_per_sqft 					 1.7975650513248986
# mean_rent 					 0.0
# mean_rent_per 					 0.0
# total_units 					 0.0
# region 					 0.0
# state_code 					 0.0
# county 					 0.0
# property_sqft 					 0.0226784435426116
# current_rent 					 0.08832656958701361
# state 					 0.0
# zip_area 					 0.0083552160420148
# property_value 					 0.13726426354738602
# income_tax_rate 					 0.0
# corporate_tax_rate 					 0.0
# state_sales_tax_rate 					 0.0
# avg_local_sales_tax_rate 					 0.0
# combined_rate 					 0.0
# max_local_sales_tax 					 0.0
# grocery_vists 					 0.0
# starbucks_vists 					 0.0
# banks 					 0.0
# colleges 					 0.0
# public_schools 					 0.0
# private_schools 					 0.0
# hospitals 					 0.0
# over16_pop 					 33.59154929577465
# over16_labor 					 33.59154929577465
# over16_employed 					 33.59154929577465
# median_income 					 33.59154929577465
# avg_household_income 					 0.0
# median_debt 					 0.0
# population 					 33.59154929577465
# ...

# %% [markdown]
# **Scale Grouped Data**

# %%
# #Scale Location data by tract/zipcode area
# group['starbucks_vists_per']=group['starbucks_vists']/group['zip_area']
# group['grocery_vists_per']=group['grocery_vists']/group['zip_area']
# group['hospitals_per']=group['hospitals']/group['zip_area']

# group['colleges_per']=group['colleges']/group['zip_area']
# #group['food_stores_per']=group['food_stores']/group['zip_area']
# group['banks_per']=group['banks']/group['zip_area']
# group['public_schools_per']=group['public_schools']/group['zip_area']

# group['private_schools_per']=group['private_schools']/group['zip_area']

# group

# %%
#Scale rent by total number of units
# group['mean_rent_scaled']=group['mean_rent']*group['total_units']
# group['mean_rent_scaled_per']=group['mean_rent_per']*group['total_units']


#add index column of tract+year
group['id'] = [''.join(str(x) for x in y) for y in map(tuple, group.index.values)]
group
# Out:
#                     growth  growth_per_sqft    mean_rent  mean_rent_per  \
# tract      year
# 1769769    2020        NaN              NaN   821.166667       1.136667
#            2021  11.441839        11.479203   915.375000       1.266667
#            2022  10.637266        10.545490  1011.300000       1.400000
# 1769770    2020        NaN              NaN   915.000000       0.950000
#            2021  12.550091        12.894737  1029.833333       1.072500
# ...                    ...              ...          ...            ...
# 2141388749 2018   3.604958         3.640439  1369.208333       1.079583
#            2019  -2.622504        -2.594340  1325.750000       1.047500
#            2020   6.680067         6.573501  1351.777778       1.129167
#            2021  13.866509        13.952979  1520.138889       1.280556
#            2022   8.248094         8.260151  1646.400000       1.387333
#
#                  total_units region state_code county  property_sqft  \
# ...

# %%
group=group[list(group.columns)[-1:]+list(group.columns)[0:len(list(group.columns))-1]]
group
# Out:
#                              id     growth  growth_per_sqft    mean_rent  \
# tract      year
# 1769769    2020     17697692020        NaN              NaN   821.166667
#            2021     17697692021  11.441839        11.479203   915.375000
#            2022     17697692022  10.637266        10.545490  1011.300000
# 1769770    2020     17697702020        NaN              NaN   915.000000
#            2021     17697702021  12.550091        12.894737  1029.833333
# ...                         ...        ...              ...          ...
# 2141388749 2018  21413887492018   3.604958         3.640439  1369.208333
#            2019  21413887492019  -2.622504        -2.594340  1325.750000
#            2020  21413887492020   6.680067         6.573501  1351.777778
#            2021  21413887492021  13.866509        13.952979  1520.138889
#            2022  21413887492022   8.248094         8.260151  1646.400000
#
#                  mean_rent_per  total_units region state_code county  \
# ...

# %%
#Percent of data that is null
mylist=100*group.isna().sum()/len(group)
print('Percent null \t\t\t\t\t Variable')

for x,y in zip(mylist,list(group.columns)):
    print(round(x,6),'%',y.rjust(50))
# Out:
# Percent null 					 Variable
# 0.0 %                                                 id
# 1.797565 %                                             growth
# 1.797565 %                                    growth_per_sqft
# 0.0 %                                          mean_rent
# 0.0 %                                      mean_rent_per
# 0.0 %                                        total_units
# 0.0 %                                             region
# 0.0 %                                         state_code
# 0.0 %                                             county
# 0.022678 %                                      property_sqft
# 0.088327 %                                       current_rent
# 0.0 %                                              state
# 0.008355 %                                           zip_area
# 0.137264 %                                     property_value
# 0.0 %                                    income_tax_rate
# ...

# %%
group.to_csv('dirty_df.csv')

# %%
df = pd.read_csv('dirty_df.csv')
df.head()
# Out:
#      tract  year           id     growth  growth_per_sqft    mean_rent  \
# 0  1769769  2020  17697692020        NaN              NaN   821.166667
# 1  1769769  2021  17697692021  11.441839        11.479203   915.375000
# 2  1769769  2022  17697692022  10.637266        10.545490  1011.300000
# 3  1769770  2020  17697702020        NaN              NaN   915.000000
# 4  1769770  2021  17697702021  12.550091        12.894737  1029.833333
#
#    mean_rent_per  total_units region  state_code  ...  stocks_bills  \
# 0       1.136667         69.5      w          30  ...        0.1793
# 1       1.266667         69.5      w          30  ...        0.2841
# 2       1.400000         69.5      w          30  ...           NaN
# 3       0.950000         88.0      w          30  ...        0.1793
# 4       1.072500         88.0      w          30  ...        0.2841
#
#    stocks_bonds  stocks_corp_bonds hist_risk  inflation   SP500  Tbill_3month  \
# ...

# %%
change_list = ['crime_rate', 'ROI_SP500', 'ROI_Tbill', 'ROI_Tbond', 'corp_bond', 'real_estate', 'sp500', 'Tbill', 
          'Tbond5', 'baa_corp_bond', 'real_estate2', 'stocks_bills', 'stocks_bonds', 'stocks_corp_bonds', 
          'hist_risk', 'inflation', 'SP500', 'Tbill_3month', 'Tbond_10year', 'baa_corp_bonds', 'real_estate3']
for i in change_list:
    df[i] = df[i].interpolate(method='linear')
df.head(7)
# Out:
#      tract  year           id     growth  growth_per_sqft    mean_rent  \
# 0  1769769  2020  17697692020        NaN              NaN   821.166667
# 1  1769769  2021  17697692021  11.441839        11.479203   915.375000
# 2  1769769  2022  17697692022  10.637266        10.545490  1011.300000
# 3  1769770  2020  17697702020        NaN              NaN   915.000000
# 4  1769770  2021  17697702021  12.550091        12.894737  1029.833333
# 5  1769770  2022  17697702022  21.204078        21.212121  1248.200000
# 6  1769872  2020  17698722020        NaN              NaN   907.333333
#
#    mean_rent_per  total_units region  state_code  ...  stocks_bills  \
# 0       1.136667         69.5      w          30  ...        0.1793
# 1       1.266667         69.5      w          30  ...        0.2841
# 2       1.400000         69.5      w          30  ...        0.2317
# 3       0.950000         88.0      w          30  ...        0.1793
# ...

# %%
df=df[df['growth'].notna()]
df=df[df['growth_per_sqft'].notna()]

df
# Out:
#             tract  year              id     growth  growth_per_sqft  \
# 1         1769769  2021     17697692021  11.441839        11.479203
# 2         1769769  2022     17697692022  10.637266        10.545490
# 4         1769770  2021     17697702021  12.550091        12.894737
# 5         1769770  2022     17697702022  21.204078        21.212121
# 7         1769872  2021     17698722021  14.465467        14.583333
# ...           ...   ...             ...        ...              ...
# 83775  2141388749  2018  21413887492018   3.604958         3.640439
# 83776  2141388749  2019  21413887492019  -2.622504        -2.594340
# 83777  2141388749  2020  21413887492020   6.680067         6.573501
# 83778  2141388749  2021  21413887492021  13.866509        13.952979
# 83779  2141388749  2022  21413887492022   8.248094         8.260151
#
#          mean_rent  mean_rent_per  total_units region  state_code  ...  \
# 1       915.375000       1.266667         69.5      w          30  ...
# ...

# %%
mylist=100*df.isna().sum()/len(df)
print('Percent null \t\t\t\t\t Variable')

for x,y in zip(mylist,list(df.columns)):
    print(round(x,1),'%',y.rjust(50))
# Out:
# Percent null 					 Variable
# 0.0 %                                              tract
# 0.0 %                                               year
# 0.0 %                                                 id
# 0.0 %                                             growth
# 0.0 %                                    growth_per_sqft
# 0.0 %                                          mean_rent
# 0.0 %                                      mean_rent_per
# 0.0 %                                        total_units
# 0.0 %                                             region
# 0.0 %                                         state_code
# 0.0 %                                             county
# 0.0 %                                      property_sqft
# 0.0 %                                       current_rent
# 0.0 %                                              state
# 0.0 %                                           zip_area
# 0.1 %                                     property_value
# ...

# %%
df[df['occupancy_rate'].isna() == True].loc[:, ['tract', 'year', 'occupancy_rate']]
# Out:
#             tract  year  occupancy_rate
# 34        1770866  2021             NaN
# 35        1770866  2022             NaN
# 144      51768870  2021             NaN
# 145      51768870  2022             NaN
# 218      57589049  2016             NaN
# ...           ...   ...             ...
# 83572  2133350242  2016             NaN
# 83573  2133350242  2017             NaN
# 83601  2137357240  2016             NaN
# 83602  2137357240  2017             NaN
# 83603  2137357240  2018             NaN
#
# [594 rows x 3 columns]

# %%
df[df['tract'] == 1003010600].loc[:, ['tract', 'year', 'occupancy_rate']]
# Out:
#             tract  year  occupancy_rate
# 48049  1003010600  2016       58.900000
# 48050  1003010600  2017       80.191667
# 48051  1003010600  2018       85.400000
# 48052  1003010600  2019             NaN
# 48053  1003010600  2020             NaN
# 48054  1003010600  2021             NaN
# 48055  1003010600  2022             NaN

# %%
# occupancy_rate backward fill
for i in list(df[df['occupancy_rate'].isna() == True].loc[:, 'tract'].unique()):
    df.loc[df['tract'] == i, 'occupancy_rate'] = df.loc[df['tract'] == i, 'occupancy_rate'].bfill(axis ='rows')

# %%
# occupancy_rate forward fill
for i in list(df[df['occupancy_rate'].isna() == True].loc[:, 'tract'].unique()):
    df.loc[df['tract'] == i, 'occupancy_rate'] = df.loc[df['tract'] == i, 'occupancy_rate'].ffill(axis ='rows')

# %%
# occupancy_rate KNNImputer
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=5)
df['occupancy_rate'] = imputer.fit_transform(df.loc[:, ['occupancy_rate']])
df.head()
# Out:
#      tract  year           id     growth  growth_per_sqft    mean_rent  \
# 1  1769769  2021  17697692021  11.441839        11.479203   915.375000
# 2  1769769  2022  17697692022  10.637266        10.545490  1011.300000
# 4  1769770  2021  17697702021  12.550091        12.894737  1029.833333
# 5  1769770  2022  17697702022  21.204078        21.212121  1248.200000
# 7  1769872  2021  17698722021  14.465467        14.583333  1038.583333
#
#    mean_rent_per  total_units region  state_code  ...  stocks_bills  \
# 1       1.266667         69.5      w          30  ...        0.2841
# 2       1.400000         69.5      w          30  ...        0.2317
# 4       1.072500         88.0      w          30  ...        0.2841
# 5       1.300000         88.0      w          30  ...        0.2317
# 7       1.008333         63.0      w          30  ...        0.2841
#
#    stocks_bonds  stocks_corp_bonds hist_risk  inflation   SP500  Tbill_3month  \
# ...

# %%
df['occupancy_rate'].isna().sum()
# Out:
# 0

# %%
# property_sqft KNNImputer
imputer = KNNImputer(n_neighbors=5)
df['property_sqft'] = imputer.fit_transform(df.loc[:, ['property_sqft']])
df['property_sqft'].isna().sum()
# Out:
# 0

# %%
# zip_area KNNImputer (7 properties)
imputer = KNNImputer(n_neighbors=5)
df['zip_area'] = imputer.fit_transform(df.loc[:, ['zip_area']])
df['zip_area'].isna().sum()
# Out:
# 0

# %%
# current_rent KNNImputer
imputer = KNNImputer(n_neighbors=5)
df['current_rent'] = imputer.fit_transform(df.loc[:, ['current_rent']])
df['current_rent'].isna().sum()
# Out:
# 0

# %%
df['property_value'].isna().sum()
# Out:
# 101

# %%
# property_value KNNImputer
imputer = KNNImputer(n_neighbors=5)
df['property_value'] = imputer.fit_transform(df.loc[:, ['property_value']])
df['property_value'].isna().sum()
# Out:
# 0

# %%
# df = df.dropna(subset=['occupancy_rate'])
# df.head()

# %%
# # property_sqft
# df = df.dropna(subset=['property_sqft'])
# df.head()

# %%
# # current_rent
# df = df.dropna(subset=['current_rent'])
# df.head()

# %%
# # property_value
# df = df.dropna(subset=['property_value'])
# df.head()

# %%
mylist=100*df.isna().sum()/len(df)
print('Percent null \t\t\t\t\t Variable')

for x,y in zip(mylist,list(df.columns)):
    print(round(x,1),'%',y.rjust(50))
# Out:
# Percent null 					 Variable
# 0.0 %                                              tract
# 0.0 %                                               year
# 0.0 %                                                 id
# 0.0 %                                             growth
# 0.0 %                                    growth_per_sqft
# 0.0 %                                          mean_rent
# 0.0 %                                      mean_rent_per
# 0.0 %                                        total_units
# 0.0 %                                             region
# 0.0 %                                         state_code
# 0.0 %                                             county
# 0.0 %                                      property_sqft
# 0.0 %                                       current_rent
# 0.0 %                                              state
# 0.0 %                                           zip_area
# 0.0 %                                     property_value
# ...

# %%
# df['tract']=df['tract'].astype(str)
# df['county']=df['tract'].str[-9:-6]
# df['state_code']=df['tract'].str[-11:-9]

# df

# %%
#Scale Location data by tract/zipcode area
df['starbucks_vists_per']=df['starbucks_vists']/df['zip_area']
df['grocery_vists_per']=df['grocery_vists']/df['zip_area']
df['hospitals_per']=df['hospitals']/df['zip_area']

df['colleges_per']=df['colleges']/df['zip_area']
#df['food_stores_per']=df['food_stores']/df['zip_area']
df['banks_per']=df['banks']/df['zip_area']
df['public_schools_per']=df['public_schools']/df['zip_area']

df['private_schools_per']=df['private_schools']/df['zip_area']

df
# Out:
#             tract  year              id     growth  growth_per_sqft  \
# 1         1769769  2021     17697692021  11.441839        11.479203
# 2         1769769  2022     17697692022  10.637266        10.545490
# 4         1769770  2021     17697702021  12.550091        12.894737
# 5         1769770  2022     17697702022  21.204078        21.212121
# 7         1769872  2021     17698722021  14.465467        14.583333
# ...           ...   ...             ...        ...              ...
# 83775  2141388749  2018  21413887492018   3.604958         3.640439
# 83776  2141388749  2019  21413887492019  -2.622504        -2.594340
# 83777  2141388749  2020  21413887492020   6.680067         6.573501
# 83778  2141388749  2021  21413887492021  13.866509        13.952979
# 83779  2141388749  2022  21413887492022   8.248094         8.260151
#
#          mean_rent  mean_rent_per  total_units region  state_code  ...  \
# 1       915.375000       1.266667         69.5      w          30  ...
# ...

# %%
West_income_county=pd.read_csv('Western_income_0624.csv', converters={'tract': lambda x: int(x)}, index_col = 0)
West_income_county=West_income_county[['median_income','state_code','county','year']]
West_income_county.sample(40)
# Out:
#        median_income  state_code  county  year
# 12122   79888.000000           8       5  2021
# 18983   54536.000000           8     123  2022
# 42482   61670.333333          56      37  2022
# 31652   60355.666667          35      61  2021
# 10616   52012.500000           4      27  2020
# 14472  116258.000000           8      35  2019
# 11275   54946.666667           8       1  2021
# 8547    75834.000000           4      19  2016
# 26144   94554.333333          32       3  2022
# 2275    20736.000000           4      13  2016
# 3314    28333.000000           4      13  2019
# 11585   40144.500000           8       5  2016
# 836     52589.000000           4      13  2019
# 17266  108750.000000           8      69  2020
# 21255   61875.000000          16      69  2019
# 29012   57895.000000          35       1  2020
# 34057   63085.500000          41      39  2018
# 32397   62878.500000          41       5  2017
# 16426   67846.375000           8      59  2020
# ...

# %%
South_income_county=pd.read_csv('South_income_0624.csv', converters={'tract': lambda x: int(x)}, index_col = 0)
South_income_county=South_income_county[['median_income','state_code','county','year']]
South_income_county.sample(40)
# Out:
#        median_income  state_code  county  year
# 28458   46716.000000          18      33  2019
# 17147   48568.000000          13      81  2020
# 33446   26592.500000          18      97  2016
# 56469   48936.000000          28      95  2016
# 31961   68897.000000          18      91  2022
# 38389   26875.500000          21      35  2017
# 42791   36666.500000          21     127  2016
# 61198   31250.000000          47      65  2020
# 30225   51163.666667          18      67  2022
# 37777   75792.000000          21      15  2021
# 30119   43233.666667          18      65  2021
# 13250   64965.333333          13      11  2022
# 66863   38428.647059          47     161  2022
# 4328    49271.000000           1      83  2018
# 8125    42066.833333           1     127  2021
# 57162   33051.500000          28     123  2016
# 10620   27940.500000           5      81  2017
# 6910    43711.000000           1     111  2017
# 9781    47849.500000           5      45  2018
# ...

# %%
CA_income_county=pd.read_csv('CA_income_0624.csv', converters={'tract': lambda x: int(x)}, index_col = 0)
CA_income_county=CA_income_county[['median_income','state_code','county','year']]
CA_income_county.sample(40)
# Out:
#        median_income  state_code  county  year
# 24332   91537.000000           6      37  2016
# 52078   58402.000000           6      95  2021
# 33799   63334.000000           6      65  2019
# 7817    40629.000000           6      29  2021
# 8210    54223.000000           6      37  2022
# 50822  119412.000000           6      85  2018
# 1010   205170.000000           6       1  2018
# 43922  103580.000000           6      73  2020
# 28495  115675.500000           6      59  2021
# 18155   62364.000000           6      37  2020
# 11213   30772.666667           6      37  2022
# 18412   73244.000000           6      37  2018
# 28044  108929.000000           6      59  2018
# 46138   88261.000000           6      77  2017
# 53709   58085.666667           6      99  2021
# 50521  180667.000000           6      85  2018
# 28366  144297.000000           6      59  2018
# 20823   92894.833333           6      37  2021
# 41778  112801.000000           6      73  2018
# ...

# %%
FL_income_county=pd.read_csv('FL_income_0624.csv', converters={'tract': lambda x: int(x)}, index_col = 0)
FL_income_county=FL_income_county[['median_income','state_code','county','year']]
FL_income_county.sample(40)
# Out:
#        median_income  state_code  county  year
# 3954   126970.333333          12      11  2022
# 21604   53530.500000          12      99  2018
# 11284   33983.000000          12      71  2016
# 6807    55379.000000          12      33  2019
# 17204   56217.333333          12      86  2021
# 9791    59768.666667          12      57  2021
# 442     49732.000000          12       5  2017
# 22640   41891.000000          12     101  2018
# 16138   64840.000000          12      86  2019
# 12686   80938.000000          12      73  2018
# 22941   81976.000000          12     101  2018
# 2435    43811.666667          12      11  2022
# 3541    58544.333333          12      11  2022
# 1493    57108.000000          12       9  2018
# 15312   30583.000000          12      86  2019
# 10757   42821.800000          12      65  2021
# 26563  100287.333333          12     109  2021
# 19514   59001.000000          12      95  2021
# 27882   48493.000000          12     115  2017
# ...

# %%
SouthEast_income_county=pd.read_csv('SouthEast_income_0624.csv', converters={'tract': lambda x: int(x)}, index_col = 0)
SouthEast_income_county=SouthEast_income_county[['median_income','state_code','county','year']]
SouthEast_income_county.sample(40)
# Out:
#        median_income  state_code  county  year
# 2571    14712.000000           1      69  2018
# 9148    42741.833333          13      29  2022
# 5267    40978.500000           1      95  2019
# 43032   38523.000000          45      73  2019
# 19143   36388.500000          13     213  2021
# 36115  120153.000000          37     183  2018
# 29923   12602.500000          37     107  2021
# 26895   29482.000000          37      67  2017
# 1322    39879.333333           1      37  2022
# 42880   46447.166667          45      71  2021
# 40228   39630.833333          45      41  2022
# 38848   44324.666667          45      19  2021
# 8024    31042.500000           1     125  2018
# 3161    39522.500000           1      73  2020
# 32848   62777.500000          37     133  2020
# 40415   82941.000000          45      45  2020
# 14234  106491.000000          13     113  2019
# 25649   25000.000000          37      57  2017
# 25357   63750.000000          37      53  2019
# ...

# %%
SouthWest_income_county=pd.read_csv('SouthWest_income_0624.csv', converters={'tract': lambda x: int(x)}, index_col = 0)
SouthWest_income_county=SouthWest_income_county[['median_income','state_code','county','year']]
SouthWest_income_county.head()
# Out:
#    median_income  state_code  county  year
# 0        88916.5          35       1  2016
# 1        85241.0          35       1  2017
# 2        96250.0          35       1  2018
# 3        93385.5          35       1  2019
# 4        84297.0          35       1  2020

# %%
frames=[SouthWest_income_county,SouthEast_income_county,FL_income_county,CA_income_county,South_income_county,West_income_county]


income_county = pd.concat(frames)
income_county['county_median_income']=income_county['median_income']
income_county=income_county.groupby(['state_code','county','year']).median().drop(columns=['median_income'])
income_county.to_csv('income_county.csv')
income_county
# Out:
#                         county_median_income
# state_code county year
# 1          1      2016          49760.000000
#                   2017          48038.500000
#                   2018          53508.750000
#                   2019          49558.000000
#                   2020          49341.062500
# ...                                      ...
# 56         45     2018          53124.000000
#                   2019          55995.750000
#                   2020          50814.750000
#                   2021          49077.833333
#                   2022          47340.916667
#
# [11711 rows x 1 columns]

# %%
income_county=pd.read_csv('income_county.csv')
income_county
# Out:
#        state_code  county  year  county_median_income
# 0               1       1  2016          49760.000000
# 1               1       1  2017          48038.500000
# 2               1       1  2018          53508.750000
# 3               1       1  2019          49558.000000
# 4               1       1  2020          49341.062500
# ...           ...     ...   ...                   ...
# 11706          56      45  2018          53124.000000
# 11707          56      45  2019          55995.750000
# 11708          56      45  2020          50814.750000
# 11709          56      45  2021          49077.833333
# 11710          56      45  2022          47340.916667
#
# [11711 rows x 4 columns]

# %%
df=df.merge(income_county,on=['state_code','county','year'],how='left')
df
# Out:
#             tract  year              id     growth  growth_per_sqft  \
# 0         1769769  2021     17697692021  11.441839        11.479203
# 1         1769769  2022     17697692022  10.637266        10.545490
# 2         1769770  2021     17697702021  12.550091        12.894737
# 3         1769770  2022     17697702022  21.204078        21.212121
# 4         1769872  2021     17698722021  14.465467        14.583333
# ...           ...   ...             ...        ...              ...
# 82269  2141388749  2018  21413887492018   3.604958         3.640439
# 82270  2141388749  2019  21413887492019  -2.622504        -2.594340
# 82271  2141388749  2020  21413887492020   6.680067         6.573501
# 82272  2141388749  2021  21413887492021  13.866509        13.952979
# 82273  2141388749  2022  21413887492022   8.248094         8.260151
#
#          mean_rent  mean_rent_per  total_units region  state_code  ...  \
# 0       915.375000       1.266667         69.5      w          30  ...
# ...

# %%
df[df['county_median_income'].isna()]
# Out:
# Empty DataFrame
# ...

# %%
SouthWest_employed_county=pd.read_csv('SouthWest_employed_0624.csv', converters={'tract': lambda x: int(x)}, index_col = 0)
SouthWest_employed_county.head()
# Out:
#          tract  year  16+_Pop  16+_Labor  16+_Employed  state_code state  \
# 0  35001000107  2016   2181.0     1263.0        1168.0          35    NM
# 1  35001000107  2017   2149.0     1219.0        1144.0          35    NM
# 2  35001000107  2018   2073.0     1194.0        1157.0          35    NM
# 3  35001000107  2019   2106.0     1249.0        1214.0          35    NM
# 4  35001000107  2020   2180.0     1269.0        1232.0          35    NM
#
#    county
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
West_employed_county=pd.read_csv('Western_employed_0624.csv', converters={'tract': lambda x: int(x)}, index_col = 0)
#West_income['tract']=West_income['tract'].apply(lambda x: str(x).zfill(11))

West_employed_county.head()
# Out:
#         tract  year  16+_Pop  16+_Labor  16+_Employed  state_code state  \
# 0  4001942600  2016   1116.0      360.0         275.0           4    AZ
# 1  4001942600  2017   1148.0      379.0         311.0           4    AZ
# 2  4001942600  2018   1199.0      365.0         328.0           4    AZ
# 3  4001942600  2019   1334.0      429.0         372.0           4    AZ
# 4  4001942600  2020   1393.0      484.0         440.0           4    AZ
#
#    county
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
CA_employed_county=pd.read_csv('CA_employed_0624.csv', converters={'tract': lambda x: int(x)}, index_col = 0)
#West_income['tract']=West_income['tract'].apply(lambda x: str(x).zfill(11))

CA_employed_county.head()
# Out:
#         tract  year  16+_Pop  16+_Labor  16+_Employed  state_code state  \
# 0  6001400100  2016   2652.0     1643.0        1568.0           6    CA
# 1  6001400100  2017   2624.0     1608.0        1543.0           6    CA
# 2  6001400100  2018   2676.0     1669.0        1578.0           6    CA
# 3  6001400100  2019   2668.0     1680.0        1596.0           6    CA
# 4  6001400100  2020   1346.0      870.0         854.0           6    CA
#
#    county
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
FL_employed_county=pd.read_csv('FL_employed_0624.csv', converters={'tract': lambda x: int(x)}, index_col = 0)
#West_income['tract']=West_income['tract'].apply(lambda x: str(x).zfill(11))

FL_employed_county.head()
# Out:
#          tract  year  16+_Pop  16+_Labor  16+_Employed  state_code state  \
# 0  12001000200  2016  7228.00     3465.0        3012.0          12    FL
# 1  12001000200  2017  6681.00     3151.0        2923.0          12    FL
# 2  12001000200  2018  6534.00     3140.0        2913.0          12    FL
# 3  12001000200  2019  7399.00     4067.0        3851.0          12    FL
# 4  12001000200  2020  6360.75     3581.5        3356.5          12    FL
#
#    county
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
SouthEast_employed_county=pd.read_csv('SouthEast_employed_0624.csv', converters={'tract': lambda x: int(x)}, index_col = 0)
#West_income['tract']=West_income['tract'].apply(lambda x: str(x).zfill(11))

SouthEast_employed_county.head()
# Out:
#         tract  year  16+_Pop  16+_Labor  16+_Employed  state_code state  \
# 0  1001020100  2016   1580.0     1027.0         984.0           1    AL
# 1  1001020100  2017   1483.0      923.0         881.0           1    AL
# 2  1001020100  2018   1562.0      966.0         931.0           1    AL
# 3  1001020100  2019   1617.0      980.0         952.0           1    AL
# 4  1001020100  2020   1558.0      852.0         834.0           1    AL
#
#    county
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
South_employed_county=pd.read_csv('South_employed_0624.csv', converters={'tract': lambda x: int(x)}, index_col = 0)
#West_income['tract']=West_income['tract'].apply(lambda x: str(x).zfill(11))

South_employed_county.head()
# Out:
#         tract  year  16+_Pop  16+_Labor  16+_Employed  state_code state  \
# 0  1001020100  2016   1580.0     1027.0         984.0           1    AL
# 1  1001020100  2017   1483.0      923.0         881.0           1    AL
# 2  1001020100  2018   1562.0      966.0         931.0           1    AL
# 3  1001020100  2019   1617.0      980.0         952.0           1    AL
# 4  1001020100  2020   1558.0      852.0         834.0           1    AL
#
#    county
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
frames=[SouthWest_employed_county,SouthEast_employed_county,FL_employed_county,CA_employed_county,South_employed_county,West_employed_county]


employed_county = pd.concat(frames)

employed_county=employed_county.groupby(['state_code','county','year']).median()
employed_county.to_csv('employed_county.csv')
employed_county
# Out:
#                                tract      16+_Pop    16+_Labor  16+_Employed
# state_code county year
# 1          1      2016  1.001021e+09  2590.000000  1512.500000   1421.500000
#                   2017  1.001021e+09  2646.500000  1535.000000   1393.500000
#                   2018  1.001021e+09  2809.500000  1567.500000   1417.500000
#                   2019  1.001021e+09  2782.000000  1600.500000   1484.000000
#                   2020  1.001021e+09  2047.000000  1022.500000    948.500000
# ...                              ...          ...          ...           ...
# 56         45     2018  5.604595e+10  2851.000000  1652.500000   1594.000000
#                   2019  5.604595e+10  2829.500000  1680.000000   1610.500000
#                   2020  5.604595e+10  2848.500000  1514.000000   1455.000000
#                   2021  5.604595e+10  2879.333333  1598.833333   1527.666667
#                   2022  5.604595e+10  2910.166667  1683.666667   1600.333333
#
# ...

# %%
employed_county=pd.read_csv('employed_county.csv').drop(columns=['tract'])
employed_county
# Out:
#        state_code  county  year      16+_Pop    16+_Labor  16+_Employed
# 0               1       1  2016  2590.000000  1512.500000   1421.500000
# 1               1       1  2017  2646.500000  1535.000000   1393.500000
# 2               1       1  2018  2809.500000  1567.500000   1417.500000
# 3               1       1  2019  2782.000000  1600.500000   1484.000000
# 4               1       1  2020  2047.000000  1022.500000    948.500000
# ...           ...     ...   ...          ...          ...           ...
# 11706          56      45  2018  2851.000000  1652.500000   1594.000000
# 11707          56      45  2019  2829.500000  1680.000000   1610.500000
# 11708          56      45  2020  2848.500000  1514.000000   1455.000000
# 11709          56      45  2021  2879.333333  1598.833333   1527.666667
# 11710          56      45  2022  2910.166667  1683.666667   1600.333333
#
# [11711 rows x 6 columns]

# %%
employed_county = employed_county.rename(columns={col: 'county_'+col 
                        for col in employed_county.columns if col not in ['state_code', 'county','year']})

# %%
df=df.merge(employed_county,on=['state_code','county','year'],how='left')
df
# Out:
#             tract  year              id     growth  growth_per_sqft  \
# 0         1769769  2021     17697692021  11.441839        11.479203
# 1         1769769  2022     17697692022  10.637266        10.545490
# 2         1769770  2021     17697702021  12.550091        12.894737
# 3         1769770  2022     17697702022  21.204078        21.212121
# 4         1769872  2021     17698722021  14.465467        14.583333
# ...           ...   ...             ...        ...              ...
# 82269  2141388749  2018  21413887492018   3.604958         3.640439
# 82270  2141388749  2019  21413887492019  -2.622504        -2.594340
# 82271  2141388749  2020  21413887492020   6.680067         6.573501
# 82272  2141388749  2021  21413887492021  13.866509        13.952979
# 82273  2141388749  2022  21413887492022   8.248094         8.260151
#
#          mean_rent  mean_rent_per  total_units region  state_code  ...  \
# 0       915.375000       1.266667         69.5      w          30  ...
# ...

# %%
df[df['county_16+_Employed'].isna()]
# Out:
# Empty DataFrame
# ...

# %%
SouthWest_pop_county=pd.read_csv('SouthWest_pop_0624.csv', converters={'tract': lambda x: int(x)}, index_col = 0)
#West_income['tract']=West_income['tract'].apply(lambda x: str(x).zfill(11))

SouthWest_pop_county
# Out:
#              tract  year  population  white_pop  Black_pop  Native_pop  \
# 0      35001000107  2016      2514.0     2296.0      129.0         0.0
# 1      35001000107  2017      2473.0     2202.0       96.0        68.0
# 2      35001000107  2018      2442.0     2202.0       76.0       126.0
# 3      35001000107  2019      2448.0     2150.0       73.0       148.0
# 4      35001000107  2020      2489.0     2243.0       53.0       101.0
# ...            ...   ...         ...        ...        ...         ...
# 47665  48507950302  2018      7229.0     6863.0       52.0         0.0
# 47666  48507950302  2019      6898.0     6517.0       32.0         0.0
# 47667  48507950302  2020      6469.0     5789.0       32.0         0.0
# 47668  48507950302  2021      6469.0     5789.0       32.0         0.0
# 47669  48507950302  2022      6469.0     5789.0       32.0         0.0
#
#        Asian_pop  Pacific_pop  male_population  female_population  0-19_pop  \
# ...

# %%
SouthEast_pop_county=pd.read_csv('SouthEast_pop_0624.csv', converters={'tract': lambda x: int(x)}, index_col = 0)
#West_income['tract']=West_income['tract'].apply(lambda x: str(x).zfill(11))

SouthEast_pop_county
# Out:
#              tract  year  population  white_pop  Black_pop  Native_pop  \
# 0       1001020100  2016      2010.0     1668.0      264.0         0.0
# 1       1001020100  2017      1845.0     1636.0       96.0         0.0
# 2       1001020100  2018      1923.0     1609.0      161.0         0.0
# 3       1001020100  2019      1993.0     1685.0      152.0         0.0
# 4       1001020100  2020      1941.0     1537.0      235.0         0.0
# ...            ...   ...         ...        ...        ...         ...
# 45131  45091061900  2018      4576.0     3917.0      526.0         4.0
# 45132  45091061900  2019      4687.0     3989.0      540.0         7.0
# 45133  45091061900  2020      5552.0     4575.0      814.0        21.0
# 45134  45091061900  2021      5552.0     4575.0      814.0        21.0
# 45135  45091061900  2022      5552.0     4575.0      814.0        21.0
#
#        Asian_pop  Pacific_pop  male_population  female_population  0-19_pop  \
# ...

# %%
South_pop_county=pd.read_csv('South_pop_0624.csv', converters={'tract': lambda x: int(x)}, index_col = 0)
#West_income['tract']=West_income['tract'].apply(lambda x: str(x).zfill(11))

South_pop_county
# Out:
#              tract  year  population  white_pop  Black_pop  Native_pop  \
# 0       1001020100  2016      2010.0     1668.0      264.0         0.0
# 1       1001020100  2017      1845.0     1636.0       96.0         0.0
# 2       1001020100  2018      1923.0     1609.0      161.0         0.0
# 3       1001020100  2019      1993.0     1685.0      152.0         0.0
# 4       1001020100  2020      1941.0     1537.0      235.0         0.0
# ...            ...   ...         ...        ...        ...         ...
# 68392  47189031000  2018      5572.0     4948.0      204.0        42.0
# 68393  47189031000  2019      5727.0     5249.0      247.0        15.0
# 68394  47189031000  2020      6038.0     5471.0      289.0        15.0
# 68395  47189031000  2021      6038.0     5471.0      289.0        15.0
# 68396  47189031000  2022      6038.0     5471.0      289.0        15.0
#
#        Asian_pop  Pacific_pop  male_population  female_population  0-19_pop  \
# ...

# %%
FL_pop_county=pd.read_csv('FL_pop_0624.csv', converters={'tract': lambda x: int(x)}, index_col = 0)
#West_income['tract']=West_income['tract'].apply(lambda x: str(x).zfill(11))

FL_pop_county
# Out:
#              tract  year  population  white_pop  Black_pop  Native_pop  \
# 0      12001000200  2016      7295.0    5666.00     1057.0        0.00
# 1      12001000200  2017      6834.0    5046.00     1277.0        0.00
# 2      12001000200  2018      6671.0    5009.00     1081.0        0.00
# 3      12001000200  2019      7557.0    5668.00     1369.0        0.00
# 4      12001000200  2020      6618.0    4734.25     1390.5        3.25
# ...            ...   ...         ...        ...        ...         ...
# 29710  12133970303  2018      3909.0    3629.00      105.0       73.00
# 29711  12133970303  2019      4091.0    3657.00      161.0      102.00
# 29712  12133970303  2020      3999.0    3523.00      142.0       90.00
# 29713  12133970303  2021      3999.0    3523.00      142.0       90.00
# 29714  12133970303  2022      3999.0    3523.00      142.0       90.00
#
#        Asian_pop  Pacific_pop  male_population  female_population  0-19_pop  \
# ...

# %%
CA_pop_county=pd.read_csv('CA_pop_0624.csv', converters={'tract': lambda x: int(x)}, index_col = 0)
#West_income['tract']=West_income['tract'].apply(lambda x: str(x).zfill(11))

CA_pop_county
# Out:
#             tract  year  population  white_pop  Black_pop  Native_pop  \
# 0      6001400100  2016      3018.0     2193.0       92.0         0.0
# 1      6001400100  2017      2991.0     2132.0       84.0         0.0
# 2      6001400100  2018      3115.0     2122.0      128.0         0.0
# 3      6001400100  2019      3120.0     2394.0      107.0         0.0
# 4      6001400100  2020      1713.0     1240.0       79.0         1.0
# ...           ...   ...         ...        ...        ...         ...
# 56394  6115041100  2018      4447.0     3865.0       88.0        48.0
# 56395  6115041100  2019      4122.0     3550.0      124.0        49.0
# 56396  6115041100  2020      4122.0     3550.0      124.0        49.0
# 56397  6115041100  2021      4122.0     3550.0      124.0        49.0
# 56398  6115041100  2022      4122.0     3550.0      124.0        49.0
#
#        Asian_pop  Pacific_pop  male_population  female_population  0-19_pop  \
# ...

# %%
West_pop_county=pd.read_csv('Western_pop_0624.csv', converters={'tract': lambda x: int(x)}, index_col = 0)
#West_income['tract']=West_income['tract'].apply(lambda x: str(x).zfill(11))

West_pop_county
# Out:
#              tract  year  population  white_pop  Black_pop  Native_pop  \
# 0       4001942600  2016      1534.0        0.0        0.0      1520.0
# 1       4001942600  2017      1552.0        0.0        0.0      1540.0
# 2       4001942600  2018      1591.0        0.0        0.0      1586.0
# 3       4001942600  2019      1742.0        0.0        0.0      1737.0
# 4       4001942600  2020      1711.0       11.0        0.0      1707.0
# ...            ...   ...         ...        ...        ...         ...
# 42583  56045951300  2018      3814.0     3565.0        0.0        34.0
# 42584  56045951300  2019      3755.0     3718.0        0.0        10.0
# 42585  56045951300  2020      3666.0     3464.0        0.0        38.0
# 42586  56045951300  2021      3666.0     3464.0        0.0        38.0
# 42587  56045951300  2022      3666.0     3464.0        0.0        38.0
#
#        Asian_pop  Pacific_pop  male_population  female_population  0-19_pop  \
# ...

# %%
frames=[SouthWest_pop_county,SouthEast_pop_county,FL_pop_county,CA_pop_county,South_pop_county,West_pop_county]


pop_county = pd.concat(frames)

pop_county=pop_county.groupby(['state_code','county','year']).median()
pop_county.to_csv('pop_county.csv')
pop_county
# Out:
#                                tract   population    white_pop   Black_pop  \
# state_code county year
# 1          1      2016  1.001021e+09  3191.500000  2620.500000  674.500000
#                   2017  1.001021e+09  3402.500000  2637.000000  809.500000
#                   2018  1.001021e+09  3590.500000  2595.000000  776.000000
#                   2019  1.001021e+09  3546.500000  2704.500000  711.500000
#                   2020  1.001021e+09  2633.500000  1943.000000  547.375000
# ...                              ...          ...          ...         ...
# 56         45     2018  5.604595e+10  3550.000000  3285.000000   18.000000
#                   2019  5.604595e+10  3524.500000  3433.500000    8.000000
#                   2020  5.604595e+10  3471.000000  3209.000000   22.000000
#                   2021  5.604595e+10  3568.666667  3310.666667   14.666667
#                   2022  5.604595e+10  3666.333333  3412.333333    7.333333
#
# ...

# %%
pop_county=pd.read_csv('pop_county.csv').drop(columns=['tract'])
pop_county
# Out:
#        state_code  county  year   population    white_pop   Black_pop  \
# 0               1       1  2016  3191.500000  2620.500000  674.500000
# 1               1       1  2017  3402.500000  2637.000000  809.500000
# 2               1       1  2018  3590.500000  2595.000000  776.000000
# 3               1       1  2019  3546.500000  2704.500000  711.500000
# 4               1       1  2020  2633.500000  1943.000000  547.375000
# ...           ...     ...   ...          ...          ...         ...
# 11706          56      45  2018  3550.000000  3285.000000   18.000000
# 11707          56      45  2019  3524.500000  3433.500000    8.000000
# 11708          56      45  2020  3471.000000  3209.000000   22.000000
# 11709          56      45  2021  3568.666667  3310.666667   14.666667
# 11710          56      45  2022  3666.333333  3412.333333    7.333333
#
#        Native_pop   Asian_pop  Pacific_pop  male_population  \
# 0        1.500000    4.500000          0.0           1555.5
# ...

# %%
pop_county = pop_county.rename(columns={col: 'county_'+col 
                        for col in pop_county.columns if col not in ['state_code', 'county','year']})

# %%
df=df.merge(pop_county,on=['state_code','county','year'],how='left')
df
# Out:
#             tract  year              id     growth  growth_per_sqft  \
# 0         1769769  2021     17697692021  11.441839        11.479203
# 1         1769769  2022     17697692022  10.637266        10.545490
# 2         1769770  2021     17697702021  12.550091        12.894737
# 3         1769770  2022     17697702022  21.204078        21.212121
# 4         1769872  2021     17698722021  14.465467        14.583333
# ...           ...   ...             ...        ...              ...
# 82269  2141388749  2018  21413887492018   3.604958         3.640439
# 82270  2141388749  2019  21413887492019  -2.622504        -2.594340
# 82271  2141388749  2020  21413887492020   6.680067         6.573501
# 82272  2141388749  2021  21413887492021  13.866509        13.952979
# 82273  2141388749  2022  21413887492022   8.248094         8.260151
#
#          mean_rent  mean_rent_per  total_units region  state_code  ...  \
# 0       915.375000       1.266667         69.5      w          30  ...
# ...

# %%
df['pop_0_19'] = df['pop_0_19'].fillna(df['county_0-19_pop']) #fill in missing values if indices match
df['over16_employed'] = df['over16_employed'].fillna(df['county_16+_Employed']) #fill in missing values if indices match
df['over16_labor'] = df['over16_labor'].fillna(df['county_16+_Labor']) #fill in missing values if indices match
df['over16_pop'] = df['over16_pop'].fillna(df['county_16+_Pop']) #fill in missing values if indices match
df['median_income'] = df['median_income'].fillna(df['county_median_income']) #fill in missing values if indices match

# %%
df['population'] = df['population'].fillna(df['county_population']) #fill in missing values if indices match
df['white_pop'] = df['white_pop'].fillna(df['county_white_pop']) #fill in missing values if indices match
df['black_pop'] = df['black_pop'].fillna(df['county_Black_pop']) #fill in missing values if indices match
df['native_pop'] = df['native_pop'].fillna(df['county_Native_pop']) #fill in missing values if indices match
df['asian_pop'] = df['asian_pop'].fillna(df['county_Asian_pop']) #fill in missing values if indices match

df['pacific_pop'] = df['pacific_pop'].fillna(df['county_Pacific_pop']) #fill in missing values if indices match
df['male_population'] = df['male_population'].fillna(df['county_male_population'])

# %%
df['employment_rate']=df['over16_employed']/df['over16_labor']

# %%
# employment KNNImputer (2 tracts)
imputer = KNNImputer(n_neighbors=5)
df['employment_rate'] = imputer.fit_transform(df.loc[:, ['employment_rate']])
df['employment_rate'].isna().sum()
# Out:
# 0

# %%
mylist=100*df.isna().sum()/len(df)
print('Percent null \t\t\t\t\t Variable')

for x,y in zip(mylist,list(df.columns)):
    print(round(x,6),'%',y.rjust(50))
# Out:
# Percent null 					 Variable
# 0.0 %                                              tract
# 0.0 %                                               year
# 0.0 %                                                 id
# 0.0 %                                             growth
# 0.0 %                                    growth_per_sqft
# 0.0 %                                          mean_rent
# 0.0 %                                      mean_rent_per
# 0.0 %                                        total_units
# 0.0 %                                             region
# 0.0 %                                         state_code
# 0.0 %                                             county
# 0.0 %                                      property_sqft
# 0.0 %                                       current_rent
# 0.0 %                                              state
# 0.0 %                                           zip_area
# 0.0 %                                     property_value
# ...

# %%
#df.to_csv('data.csv')

# %%
df
# Out:
#             tract  year              id     growth  growth_per_sqft  \
# 0         1769769  2021     17697692021  11.441839        11.479203
# 1         1769769  2022     17697692022  10.637266        10.545490
# 2         1769770  2021     17697702021  12.550091        12.894737
# 3         1769770  2022     17697702022  21.204078        21.212121
# 4         1769872  2021     17698722021  14.465467        14.583333
# ...           ...   ...             ...        ...              ...
# 82269  2141388749  2018  21413887492018   3.604958         3.640439
# 82270  2141388749  2019  21413887492019  -2.622504        -2.594340
# 82271  2141388749  2020  21413887492020   6.680067         6.573501
# 82272  2141388749  2021  21413887492021  13.866509        13.952979
# 82273  2141388749  2022  21413887492022   8.248094         8.260151
#
#          mean_rent  mean_rent_per  total_units region  state_code  ...  \
# 0       915.375000       1.266667         69.5      w          30  ...
# ...
